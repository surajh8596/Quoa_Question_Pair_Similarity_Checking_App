# %% [markdown]
# <h1 style="color:brown; background:pink; line-height:2; text-align:center; font-family:Arial Black;">* COMPARING RESULTS OF ALL APPROACHES, TECHNIQUES AND ALGORITHMS USED IN THE QUORA QUESTION PAIR SIMILARITY PROJECT * </h1>

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">ALL EXPERMETS LIST</h1>

# %% [markdown]
# ![all_exp.jpg](attachment:all_exp.jpg)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Simple Approach without Text Preprocessing and Without Data Balancing</h1>

# %% [markdown]
# ![sipmle_app.jpg](attachment:sipmle_app.jpg)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Simple Approach with Text Preprocessing, BOW and without Data Balance</h1>

# %% [markdown]
# ![simple_app1.jpg](attachment:simple_app1.jpg)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;"> Simple Approach with Text Preprocessing,TFIDF, without Data Balance</h1>

# %% [markdown]
# ![simple_app2.jpg](attachment:simple_app2.jpg)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Simple Approach with Text Preprocessing, BOW, TFIDF and Balanced Data of 50K</h1>

# %% [markdown]
# ![simple_app3.jpg](attachment:simple_app3.jpg)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Basic and Advanced Extracted Features, BOW and Balanced Data of 50K</h1>

# %% [markdown]
# ![adv_1.png](attachment:adv_1.png)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Advanced Extracted Features, Own Word Embedding and Balanced Data of 50K</h1>

# %% [markdown]
# ![adv_2.png](attachment:adv_2.png)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Advanced Extracted Features, Pre-Trained Word2Vec, GloVe, BERT and Balanced Data of 50K</h1>

# %% [markdown]
# ![pre_train_50k.png](attachment:pre_train_50k.png)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Advanced Extracted Features, Pre-Trained BERT and Balanced Data of 3 Lakh</h1>

# %% [markdown]
# ![bert_3lakh.png](attachment:bert_3lakh.png)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Advanced Extracted Features, using BOW, TFIDF and Complete Data</h1>

# %% [markdown]
# ![adv_3.png](attachment:adv_3.png)

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Advanced Extracted Features, Pre-Trained Word2Vec and Complete Data</h1>

# %% [markdown]
# ![word_full.png](attachment:word_full.png)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Advanced Extracted Features, Pre-Trained GloVE and Complete Data</h1>

# %% [markdown]
# ![glove_full.png](attachment:glove_full.png)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue; background:lightgreen;">Advance Approach with Text Preprocessing and Advanced Extracted Features, Pre![image.png](attachment:image.png)-Trained BERT and Complete Data</h1>

# %% [markdown]
# ![bert_full.png](attachment:bert_full.png)

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# <h1 style="color:blue;">Using BERT as a Text to Vector Conversion method with XGBoost as a ML Model we recieved 86% Accuracy.</h1>
