# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Project Details *</h1>

# %% [markdown]
# <h3><div style="background:lightgreen; line-height:2">
#     <b style="color:blue; font-family:Arial Black">Project Title &emsp;:&ensp; </b><b style="color:green">Quora Question Pair Similarity</b><br>
#     <b style="color:blue; font-family:Arial Black">Technologies &ensp;:&ensp; </b><b style="color:green">ML, NLP, MLOPs, Streamlit, AWS Cloud</b><br>
#     <b style="color:blue; font-family:Arial Black">Domain &emsp;&emsp;&emsp;&nbsp;&nbsp;:&ensp; </b><b style="color:green">Social Networking</b><br>
#     <b style="color:blue; font-family:Arial Black">Team Name &emsp;&nbsp;:&ensp; </b><b style="color:green">Team Data Dynamos</b><br>
#     <b style="color:blue; font-family:Arial Black">Participants &emsp;:&ensp; </b><b style="color:green">1. Rini Varghese &ensp; 2. Shweta Kulkarni &ensp; 3. Suraj Honkamble <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 4. Uma Naga Silpa Bhupathiraju &ensp; 5. Utkarsha A Narkhede</b>
# </div></h3>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Problem Statement *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">Over 100 million people visit Quora every month, so it's no surprise that many people ask similarly worded questions. Multiple questions with the same intent can cause seekers to spend more time finding the best answer to their question, and make writers feel they need to answer multiple versions of the same question. Quora values canonical questions because they provide a better experience to active seekers and writers, and offer more value to both of these groups in the long term. The main aim of the project is to predict whether a pair of questions are similar or not. </h3>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* About Dataset *</h1>

# %% [markdown]
# <h3><div style=" line-height:1.2">
#     <h3 style="color:orange">Columns Information:</h3>
#     <b style="color:orange;">id &ensp;&ensp;&nbsp;&emsp;&emsp;&emsp;&emsp;&emsp;:&ensp; </b><b style="color:gray">Unique ID for each rows.</b><br>
#     <b style="color:orange;">qid1 &nbsp;&ensp;&nbsp;&emsp;&emsp;&emsp;&emsp;:&ensp; </b><b style="color:gray">Unique ID for Question-1.</b><br>
#     <b style="color:orange;">qid2 &ensp;&ensp;&emsp;&emsp;&emsp;&emsp;:&ensp; </b><b style="color:gray">Unique ID for Question-2.</b><br>
#     <b style="color:orange;">question1 &emsp;&emsp;&ensp;:&ensp; </b><b style="color:gray">Question-1 Content</b><br>
#     <b style="color:orange;">question2 &ensp;&emsp;&emsp;:&ensp; </b><b style="color:gray">Question-2 Content</b><br>
#     <b style="color:orange;">is_duplicate &ensp;&emsp;:&ensp; </b><b style="color:gray">Target variable. 1 if question1 & question2 have essentially the same meaning, 0 otherwise.</b><br>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Business Objectives and Constraints *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">1. The cost of a Mis-Classification can be very high.<br>
# 2. We need probability of a pair of questions to be duplicates so that we can choose any threshold of choice.<br>
# 3. No strict latency concerns.<br>
# 4. Interpretability is partially important.</h3>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Task to Perform *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2;">1. Import the General libraries, NLP module, and Machine learning modules.<br>
#                         2. Load the dataset.<br>
#                         3. Text Preprocessing:<br>
#                         &ensp;&ensp;&ensp; i.   Removing html tags <br>
#                         &ensp;&ensp;&ensp; ii.  Removing Punctuations <br>
#                         &ensp;&ensp;&ensp; iii. Performing stemming <br>
#                         &ensp;&ensp;&ensp; iv.  Removing Stop words <br>
#                         &ensp;&ensp;&ensp; v.   Expanding contractions. <br>
#                         4. Apply Tokenization. <br>
#                         5. Apply Stemming. <br>
#                         6. Apply POS Tagging. <br>
#                         7. Apply Lemmatization. <br>
#                         8. Apply label encoding. <br>
#                         9. Feature Extraction. <br>
#                         10 Text to Numerical vector conversion:<br>
#                         &ensp;&ensp;&ensp; i.   Apply BOW(Count-Vectorizer). <br>
#                         &ensp;&ensp;&ensp; ii.  Apply TFIDF vectorizer. <br>
#                         &ensp;&ensp;&ensp; iii. Apply Word2Vector vectorizer. <br>
#                         &ensp;&ensp;&ensp; iv.  Apply Glove. <br>
#                         11. Data preprocessing. <br>
#                         12. Model Building. <br>
#                         13. Evaluate the model:<br>
#                         &ensp;&ensp;&ensp; i.   Confusion Matrix. <br>
#                         &ensp;&ensp;&ensp; ii.  Classification report. <br>
#                         14. Tracking experiments with the help of MLFlow. <br>
#                         15. Break code into production ready script. <br>
#                         16. Automation using Workflow Orchestration using Prefect.<br>
#                         17. Build Streamlit Data app to check whether pair of questions are similar or not. Deploy to streamlit cloud.<br>
#                         18. Deploy Streamlit app to AWS Cloud.</h3>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Type of Machine Learning Problem *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2">It is a binary classification problem, for a given pair of questions we need to predict if they are duplicate or not.</h3>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Terms Used in NLP *</h1>

# %% [markdown]
# <h3><div style=" line-height:1.2">
#     <b style="color:orange;">Document &emsp;&emsp;:&ensp; </b><b style="color:gray">Each row in dataset is called Document.</b><br>
#     <b style="color:orange;">Corpus &nbsp;&emsp;&emsp;&emsp;:&ensp; </b><b style="color:gray">Collection of Documents(all rows) is called Corpus.</b><br>
#     <b style="color:orange;">Vocabulary &ensp;&emsp;:&ensp; </b><b style="color:gray">Unique Words in Corpus</b><br>
#     <b style="color:orange;">Segmentation &nbsp;:&ensp; </b><b style="color:gray">Breaking multiple sentences into single individual sentence is called Segmentation.</b><br>
#     <b style="color:orange;">Tokenization &nbsp;&ensp;:&ensp; </b><b style="color:gray">Process of breaking sentence into Words is called Tokenization and the words are called Tokens.</b><br>
#     <b style="color:orange;">StopWords &ensp;&emsp;:&ensp; </b><b style="color:gray">Common words used in any language are called Stop-Words</b><br>
#     <b style="color:orange;">Stemming &emsp;&emsp;:&ensp; </b><b style="color:gray">Process of removing or replacing suffixes of word to get the root or base word is called <br> &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;Stemming. But sometimes meaning of word will lost.</b><br>
#     <b style="color:orange;">Lemmatization :&ensp; </b><b style="color:gray">Process of removing or replacing suffixes of word to get the root or base word is called <br> &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; Lemmatization. Here words have dictionary meaning.</b><br>
#     <b style="color:orange;">NER Tagging &ensp;&nbsp;:&ensp; </b><b style="color:gray">Process of Adding Tags to each word like "Person, Place, Currency" etc. is called NER Tagging.</b><br>
#      <b style="color:orange;">POS Tagging &ensp;&nbsp;:&ensp; </b><b style="color:gray">Process of Adding Part of Speech Tags to each word is called POS Tagging..</b><br>
#     <b style="color:orange;">Chunking &emsp;&nbsp;&emsp;:&ensp; </b><b style="color:gray">Process of Conversion of sentence to a flat tree is called Chunking.</b><br>
# </div></h3>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Text Pre-Processing Steps *</h1>

# %% [markdown]
# <h3><p style="color:gray; line-height:1.1">Text preprocessing is a crucial step in NLP. Cleaning our text data in order to convert it into a presentable form that is analyzable and predictable for our task is known as text preprocessing.<br>
# Many steps can be taken in text preprocessing, few steps are,<br>
# <b style="color:orange">A. Basic Techniques:</b><br>
#     &ensp;&ensp;1. Lowering Case<br>
#     &ensp;&ensp;2. Remove Punctuations<br>
#     &ensp;&ensp;3. Removal of special characters and Numbers<br>
#     &ensp;&ensp;4. Removal of HTML tags<br>
#     &ensp;&ensp;5. Removal of URL's<br>
#     &ensp;&ensp;6. Removal of Extra Spaces<br>
#     &ensp;&ensp;7. Expanding Contraction<br>
#     &ensp;&ensp;8. Text Correction<br>
# <b style="color:orange">B. Advanced Techniques:</b><br>
#     &ensp;&ensp;1. Apply Tokenization<br>
#     &ensp;&ensp;2. Stop Word Removal<br>
#     &ensp;&ensp;3. Apply Stemming<br>
#     &ensp;&ensp;4. Apply Lemmatization<br>
# <b style="color:orange">C. More Advanced Techniques:</b><br>
#     &ensp;&ensp;1. POS(Part Of Speech) Tagging<br>
#     &ensp;&ensp;2. NER(Name Entity Recognation)<br></p></h3>

# %% [markdown]
# <h2 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">A. Basic Techniques</h2>

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">1. Lowering Case</h3>

# %% [markdown]
# <h3><p style="color:gray; line-height:1.1"><b style="color:black"> Lowering Case of text is essential step in text preprocessing due to following reasons:</b><br>
#     &emsp;&emsp; 1. The same words, one in upper case and other in lower case are considered as different words while creating
#                     BOW, hence lowering add the same value for both the words.<br>
#     &emsp;&emsp; 2. In TF-IDF CountVectorization techniques the frequency of words is considered with irrespective of the case.<br>
#     &emsp;&emsp; 3. Lowering decreasing the size of the vocabulary and hence reduce the dimensionality.</p></h3>

# %%
sentence="What is the STEP by step guide to invest In share market in india?"
sentence_lower=str(sentence).lower()
print("Original Sentence:", sentence)
print("--"*60)
print("Lowered Sentence:", sentence_lower)
# Out:
# Original Sentence: What is the STEP by step guide to invest In share market in india?
# ------------------------------------------------------------------------------------------------------------------------
# Lowered Sentence: what is the step by step guide to invest in share market in india?

# %% [markdown]
# **<code style="color:green;">In the `Original Sentence` we have two `Step` with different cases and same meaning in sentence, after coverting everything to lower both words look similar and we reduced the dimensionality.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">2. Removing Punctuations</h3>
# <h3><p style="color:orange; line-height:1.1">To remove Punctuations we are going to use python "String" library.</p></h3>

# %%
import string
punc=string.punctuation
punc
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# **<code style="color:green">Above are the Punctuations in any language</code>**

# %%
sentence="Hello Everyone, this is team Data Dynamos ! We are got an project of Quora Question SImilirity ^ . We are actually happy !! Because we wanted this project * *"
without_punc=[word for word in sentence.split(" ") if word not in list(punc)]
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence without Punctuations:", " ".join(without_punc))
# Out:
# Original Sentence: Hello Everyone, this is team Data Dynamos ! We are got an project of Quora Question SImilirity ^ . We are actually happy !! Because we wanted this project * *
# ------------------------------------------------------------------------------------------------------------------------
# Sentence without Punctuations: Hello Everyone, this is team Data Dynamos We are got an project of Quora Question SImilirity We are actually happy !! Because we wanted this project

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">3. Removing Special Characters and Numbers</h3>

# %% [markdown]
# <h3><p style="color:gray; line-height:1.1">Special Characters and numbers like "!,@,#,%,^,&,$,+,*, 1 to 9" have no meaning in the sentence and they do not contribute to any sentence classification. And there is one senario when these special characters attached to any word will considered as different word which is already present in the sentence. eg. "Shocked" and "Shocked!" considered as different words but we know they have same meaning. Hence its better to remove any special characters there for dimensionality is also reduces.<br>
# <b style="color:orange">We are going to use python "re package" to remove special characters and numbers.</b></p></h3>

# %%
import re
sentence="Find the remainder when [math]23^{24}[/math] is divided by 24,23?"
sentence_clean=re.sub("[^a-zA-Z]", " ", sentence)
print("Original Sentence:", sentence)
print("--"*60)
print("Clean Sentence:", sentence_clean)
# Out:
# Original Sentence: Find the remainder when [math]23^{24}[/math] is divided by 24,23?
# ------------------------------------------------------------------------------------------------------------------------
# Clean Sentence: Find the remainder when  math          math  is divided by

# %% [markdown]
# **<code style="color:green">In `Original Sentence` "{},[],/,?,^" are the special characters, `Clean Sentence` contains no special characters and numbers.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">4. Removal of HTML Tags</h3>

# %% [markdown]
# <h3><p style="color:gray; line-height:1">When we Scrap data from any website then dataset contains HTML tags. We might face problem if HTML Tags present in our dataset. Hence it prefered to remove these tags.</p></h3>

# %%
sentence='''<h3 style="color:red; font-family:Arial Black">Hello Guys How Are You</h3>'''
clean_sentence=re.sub("<.*?>", "", sentence)
print("Original Sentence:", sentence)
print("--"*60)
print("Clean Sentence:", clean_sentence)
# Out:
# Original Sentence: <h3 style="color:red; font-family:Arial Black">Hello Guys How Are You</h3>
# ------------------------------------------------------------------------------------------------------------------------
# Clean Sentence: Hello Guys How Are You

# %% [markdown]
# **<code style="color:green;">The Original Sentence contains HTML tags, after removing these tags using re.sub function of python regex, our Sentence looks human readable.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">5. Removing URL's</h3>

# %% [markdown]
# <h3><p style="color:gray; line-height:1">Some times in the Quora question people provide some external links and url's. As we know that the urls are the random combinations of strings which does not cotains any specific meaning. Hence is useful to remove thes urls.</p></h3>

# %%
sentence="I visited https://github.com/surajh8596/NLP-Sentiment-Analysis-/tree/main/Sentiment%20Analysis link and I found very interesting sentiment analysis projects."
clean_sentence=re.sub("(http|https|www)\S+", "", sentence)
print("Original Sentence:", sentence)
print("--"*60)
print("Clean Sentence:", clean_sentence)
# Out:
# Original Sentence: I visited https://github.com/surajh8596/NLP-Sentiment-Analysis-/tree/main/Sentiment%20Analysis link and I found very interesting sentiment analysis projects.
# ------------------------------------------------------------------------------------------------------------------------
# Clean Sentence: I visited  link and I found very interesting sentiment analysis projects.

# %% [markdown]
# **<code style="color:green">Original sentence conatins an external website link, which cause problem in our analysis. So after removing this link check the clean sentence, with no url.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">6. Removing Extra Spaces</h3>

# %% [markdown]
# <h3><p style="color:gray; line-height:1">There is some senario where users insert extra spaces at the start, at the end or at the anywhere in the sentence. We need to remove all the extra spaces inserted by an user.</p></h3>

# %%
sentence="Hi Team    Data Dynamos, How is your     project going on            ?"
clean_sentence=re.sub(" +"," ", sentence)
print("Original Sentence:", sentence)
print("--"*60)
print("Clean Sentence:", clean_sentence)
# Out:
# Original Sentence: Hi Team    Data Dynamos, How is your     project going on            ?
# ------------------------------------------------------------------------------------------------------------------------
# Clean Sentence: Hi Team Data Dynamos, How is your project going on ?

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">7. Expanding Contraction</h3>

# %% [markdown]
# <h3><p style="color:gray; line-height:1.2">Contractions are words or combinations of words that are shortened by dropping letters and replacing them by an apostrophe. Nowadays, where everything is shifting online, we communicate with others more through text messages or posts on different social media like Facebook, Instagram, Whatsapp, Twitter, LinkedIn, etc. in the form of texts. With so many people to talk, we rely on abbreviations and shortened form of words for texting people.<br><br>
# <b style="color:orange">We need to exapnd these contractions so that we can easliy apply tokenization and normalization(stemming and lemmatization). Here we are going to use <b style="color:green">contrations</b> python library to exapand the constraction words.</b></p></h3>

# %%
import contractions

# %%
sentence="We've reached final step of our data science internship. We'll meet u in project presentation."
clear_sentence=contractions.fix(sentence)
print("Original Sentence:", sentence)
print("--"*60)
print("Clear Sentence:", clear_sentence)
# Out:
# Original Sentence: We've reached final step of our data science internship. We'll meet u in project presentation.
# ------------------------------------------------------------------------------------------------------------------------
# Clear Sentence: We have reached final step of our data science internship. We will meet you in project presentation.

# %% [markdown]
# **<code style="color:green">Original Sentence contains contraction words like `"We've","We'll","u"`. And the expanded words for these constraction are `"We have","We will", "You"`.</code>**

# %% [markdown]
# <p> <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">8. Text Correction</h3>
# <h3 style="color:orange">To correct the text we are going to use TextBlob from NLTK</h3></p>

# %%
from textblob import TextBlob
sentence="We have reachedd final step of our data science Trainig. We'll meet youu in project presentatiom."
textblob=TextBlob(sentence)
correct_sentence=textblob.correct()
print("Original Sentence:", sentence)
print("--"*60)
print("Correct Sentence:", correct_sentence)
# Out:
# Original Sentence: We have reachedd final step of our data science Trainig. We'll meet youu in project presentatiom.
# ------------------------------------------------------------------------------------------------------------------------
# Correct Sentence: He have reached final step of our data science Training. He'll meet you in project presentation.

# %% [markdown]
# <h2 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">B. Advanced Techniques</h2>

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">1. Apply Tokenization</h3>

# %% [markdown]
# <h3><p style="color:gray; line-height:1.1">Tokenization is a process of breaking down sentence into words. These words are called Tokens. Here, tokens can be either words, characters, or subwords.<br>
# <b style="color:orange">Tokenization is broadly classified into 3 types:</b><br>
#     &ensp;&ensp;a. Sentence Tokenization<br>
#     &ensp;&ensp;b. Word Tokenization<br>
#     &ensp;&ensp;c. SubWord(n-gram characters) Tokenization<br><br>
# <b style="color:orange">Here we can use string "Split" method for word tokenization only. For Charcter and SubWord Tokenization we need to use "NLTK" inbuit funvtion.</b></p></h3>

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">a. Sentence Tokenization</h3>

# %%
from nltk.tokenize import sent_tokenize
sentence='''Our Team name is Team Data Dynamos and we have selected Quora question similarity project. We have started working on this project from 13th of May only. Working with team gives little extra space to apply new things.'''
tokens=sent_tokenize(sentence)
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence Tokens:", tokens)
# Out:
# Original Sentence: Our Team name is Team Data Dynamos and we have selected Quora question similarity project. We have started working on this project from 13th of May only. Working with team gives little extra space to apply new things.
# ------------------------------------------------------------------------------------------------------------------------
# Sentence Tokens: ['Our Team name is Team Data Dynamos and we have selected Quora question similarity project.', 'We have started working on this project from 13th of May only.', 'Working with team gives little extra space to apply new things.']

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">b. Word Tokenization</h3>

# %%
sentence='''Our Team name is Team Data Dynamos and we have selected Quora question similarity project.?'''
tokens=sentence.split(" ")
print("Original Sentence:", sentence)
print("--"*60)
print("Word Tokens:", tokens)
# Out:
# Original Sentence: Our Team name is Team Data Dynamos and we have selected Quora question similarity project.?
# ------------------------------------------------------------------------------------------------------------------------
# Word Tokens: ['Our', 'Team', 'name', 'is', 'Team', 'Data', 'Dynamos', 'and', 'we', 'have', 'selected', 'Quora', 'question', 'similarity', 'project.?']

# %%
from nltk.tokenize import word_tokenize
sentence='''Our Team name is Team Data Dynamos and we have selected Quora question similarity project.?'''
tokens=word_tokenize(sentence)
print("Original Sentence:", sentence)
print("--"*60)
print("Word Tokens:", tokens)
# Out:
# Original Sentence: Our Team name is Team Data Dynamos and we have selected Quora question similarity project.?
# ------------------------------------------------------------------------------------------------------------------------
# Word Tokens: ['Our', 'Team', 'name', 'is', 'Team', 'Data', 'Dynamos', 'and', 'we', 'have', 'selected', 'Quora', 'question', 'similarity', 'project', '.', '?']

# %% [markdown]
# **<code style="color:green">We can easily see the difference, when we tokenize using string method, it will consider all the special characters & punctuation attached to a word as a part of that word, but when we tokenize using NLTK word_tokenizer it consider those special characters & punctuation as a seperate toke.</code>**

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">c. Sub-Word(n-gram character) Tokenization</h3>
# <h3 style="color:gray; line-height:1.1">N-grams are continuous sequences of words or symbols, or tokens in a document. In technical terms, they can be defined as the neighboring sequences of items in a document.<h3>

# %%
from nltk import ngrams

# %%
sentence='''Our Team name is Team Data Dynamos and we have selected Quora question similarity project. We have started working on this project from 13th of May only. Working with team gives little extra space to apply new things.'''
n_gram_tokens=list(ngrams((sentence.split(" ")), n=3))
print("Original Sentence:", sentence)
print("--"*60)
print("N-gram Tokens:", n_gram_tokens)
# Out:
# Original Sentence: Our Team name is Team Data Dynamos and we have selected Quora question similarity project. We have started working on this project from 13th of May only. Working with team gives little extra space to apply new things.
# ------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">2. Remove Stop Words</h3>

# %%
from nltk.corpus import stopwords
stopwords_en=stopwords.words("english")
print("Total Stop Words in English=", len(stopwords_en))
# Out:
# Total Stop Words in English= 179

# %% [markdown]
# **<code style="color:green">English language contains 179 Stop WOrds.</code>**

# %%
sentence="Our Team name is Team Data Dynamos and we have selected Quora question similarity project"
sentence_non_stopword=[word for word in sentence.split(" ") if not word in stopwords_en]
print("Sentence with StopWOrds:", sentence)
print("--"*60)
print("Sentence without StopWOrds:", " ".join(sentence_non_stopword))
# Out:
# Sentence with StopWOrds: Our Team name is Team Data Dynamos and we have selected Quora question similarity project
# ------------------------------------------------------------------------------------------------------------------------
# Sentence without StopWOrds: Our Team name Team Data Dynamos selected Quora question similarity project

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">3. Apply Stemming</h3>
# <h3><p style="color:orange;"><b>Types of Stemmer in NLP:</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">a. Porter Stemmer</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">b. SnowBall Stemmer</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">c. Lancaster Stemmer</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">d. Regexp Stemmer</b><br>
# </p></h3>

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">a. Porter Stemmer</h3>
# <h3 style="color:gray">Porter Stemmer is the original stemmer but the stem sometimes illogical or non-dictionary word.</h3>

# %%
from nltk.stem import PorterStemmer
porter=PorterStemmer()
sentence="Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling"
porter_stem=[porter.stem(word) for word in sentence.split(" ")]
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence after Porter Stemming:", " ".join(porter_stem))
# Out:
# Original Sentence: Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling
# ------------------------------------------------------------------------------------------------------------------------
# Sentence after Porter Stemming: connect connect connect connect connect connect connect drive driven drive abl abl enabl enabl enabl

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">b. Snowball Stemmer</h3>
# <h3 style="color:gray">Snowball stemmer is faster and more logical than the Porter Stemmer.</h3>

# %%
from nltk.stem import SnowballStemmer
snowball=SnowballStemmer(language="english")
sentence="Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling"
snowball_stem=[snowball.stem(word) for word in sentence.split(" ")]
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence after Porter Stemming:", " ".join(snowball_stem))
# Out:
# Original Sentence: Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling
# ------------------------------------------------------------------------------------------------------------------------
# Sentence after Porter Stemming: connect connect connect connect connect connect connect drive driven drive abl abl enabl enabl enabl

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">c. Lancaster Stemmer</h3>
# <h3 style="color:gray">The Lancaster stemmers are more aggressive and dynamic. The stemmer is really faster, but the algorithm is really confusing when dealing with small words. Lancaster Stemmer produces results with excessive stemming.</h3>

# %%
from nltk.stem import LancasterStemmer
lancaster=LancasterStemmer()
sentence="Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling"
lancaster_stem=[lancaster.stem(word) for word in sentence.split(" ")]
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence after Porter Stemming:", " ".join(lancaster_stem))
# Out:
# Original Sentence: Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling
# ------------------------------------------------------------------------------------------------------------------------
# Sentence after Porter Stemming: connect connect connect connect connect connect connect driv driv driv abl abl en en en

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">d. Regexp Stemmer</h3>
# <h3 style="color:gray">Regexp stemmer identifies morphological affixes using regular expressions. Substrings matching the regular expressions will be discarded.</h3>

# %%
from nltk.stem import RegexpStemmer
regex=RegexpStemmer(regexp="ing$|s$|e$", min=0)
sentence="Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling"
regex_stem=[regex.stem(word) for word in sentence.split(" ")]
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence after Porter Stemming:", " ".join(regex_stem))
# Out:
# Original Sentence: Connect Connection Connections Connecting Connected Connects Connectings Driving Driven Drives Able Ables Enable Enables Enabling
# ------------------------------------------------------------------------------------------------------------------------
# Sentence after Porter Stemming: Connect Connection Connection Connect Connected Connect Connecting Driv Driven Drive Abl Able Enabl Enable Enabl

# %% [markdown]
# **<code style="color:green">All Stemmers are Different from each other. Ther is one common thing between all stemmers, sometimes they did not return the stem with logical or dictionary meaning.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">4. Apply Lemmatization</h3>
# <h3><p style="color:orange;"><b>Types of Lemmatization in NLP:</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">a. Wordnet Lemmatizer</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">b. TextBlob Lemmatizer</b><br>
# </p></h3>

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">a. Wordnet Lemmatizer</h3>

# %%
from nltk.stem import WordNetLemmatizer
lemma=WordNetLemmatizer()
sentence="The bats are hanging on their feet in upright positions"
sentence_lemma=[lemma.lemmatize(word, 'v') for word in sentence.split(" ")]
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence after Lemmatization:", " ".join(sentence_lemma))
# Out:
# Original Sentence: The bats are hanging on their feet in upright positions
# ------------------------------------------------------------------------------------------------------------------------
# Sentence after Lemmatization: The bat be hang on their feet in upright position

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">b. TextBlob Lemmatizer</h3>

# %%
from textblob import TextBlob, Word
sentence="The bats are hanging on their feet in upright positions"
sent=TextBlob(sentence)
texblob_lemma=[w.lemmatize() for w in sent.words]
print("Original Sentence:", sentence)
print("--"*60)
print("Sentence after Lemmatization:", " ".join(texblob_lemma))
# Out:
# Original Sentence: The bats are hanging on their feet in upright positions
# ------------------------------------------------------------------------------------------------------------------------
# Sentence after Lemmatization: The bat are hanging on their foot in upright position

# %% [markdown]
# <h2 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">C. More Advanced Techniques</h2>
# <p><h3 style="color:gray;">These Techniques are not used in all the tasks, these are problem specific. These techniques are mainly used in QA System(Question Answer), Word Sense Disambiguiation etc.</h3>
# <h3 style="color:orange;">More Advanced Techniques are:<br>
#     &emsp;&emsp;&emsp;<b style="color:gray">1. POS(Part of Speech) Tagging</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">2. NER(Name Entity Recognisation) Tagging</b><br>
# </h3></p>

# %% [markdown]
# <p><h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">1. POS Tagging</h3>
# <h3 style="color:gray;">Adding a Part of Speech tags to every word in the corpus is called POS tagging. If we want to perform POS tagging then no need to remove stopwords. This is one of the essential steps in the text analysis where we know the sentence structure and which word is connected to the other, which word is rooted from which, eventually, to figure out hidden connections between words which can later boost the performance of our Machine Learning Model.<br>
#     <b style="color:orange">POS Tagging can be performed using two Libraries</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">a. POS Tagging using NLTK</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">b. POS Tagging using Spacy</b><br>
# </h3></p>

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">a. POS Tagging using NLTK</h3>

# %%
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
doc=word_tokenize("What is the step by step guide to invest in share market in india")
for i in range(len(doc)):
    print("Word:",pos_tag(doc)[i][0], "||", "POS Tag:", pos_tag(doc)[i][1])
# Out:
# Word: What || POS Tag: WP
# Word: is || POS Tag: VBZ
# Word: the || POS Tag: DT
# Word: step || POS Tag: NN
# Word: by || POS Tag: IN
# Word: step || POS Tag: NN
# Word: guide || POS Tag: RB
# Word: to || POS Tag: TO
# Word: invest || POS Tag: VB
# Word: in || POS Tag: IN
# Word: share || POS Tag: NN
# Word: market || POS Tag: NN
# Word: in || POS Tag: IN
# Word: india || POS Tag: NN

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">b. POS Tagging using Spacy</h3>

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")
doc=nlp("What is the step by step guide to invest in share market in india")
for word in doc:
    print("Word:", word.text,"||","POS:", word.pos_, "||", "POS Tag:", word.tag_, "||", "Explanation:", spacy.explain(word.tag_))
# Out:
# Word: What || POS: PRON || POS Tag: WP || Explanation: wh-pronoun, personal
# Word: is || POS: AUX || POS Tag: VBZ || Explanation: verb, 3rd person singular present
# Word: the || POS: DET || POS Tag: DT || Explanation: determiner
# Word: step || POS: NOUN || POS Tag: NN || Explanation: noun, singular or mass
# Word: by || POS: ADP || POS Tag: IN || Explanation: conjunction, subordinating or preposition
# Word: step || POS: NOUN || POS Tag: NN || Explanation: noun, singular or mass
# Word: guide || POS: NOUN || POS Tag: NN || Explanation: noun, singular or mass
# Word: to || POS: PART || POS Tag: TO || Explanation: infinitival "to"
# Word: invest || POS: VERB || POS Tag: VB || Explanation: verb, base form
# Word: in || POS: ADP || POS Tag: IN || Explanation: conjunction, subordinating or preposition
# Word: share || POS: NOUN || POS Tag: NN || Explanation: noun, singular or mass
# Word: market || POS: NOUN || POS Tag: NN || Explanation: noun, singular or mass
# ...

# %% [markdown]
# **<code style="color:green">Spacy is more powerful than NLTK. Spacy is faster and Grammatically accurate.</code>**

# %% [markdown]
# <p><h3 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">2. NER Tagging</h3>
# <h3 style="color:gray;">Named entity recognition (NER) is a natural language processing (NLP) method that extracts information from text. NER involves detecting and categorizing important information in text known as named entities. Named entities refer to the key subjects of a piece of text, such as names, locations, companies, events and products, as well as themes, topics, times, monetary values and percentages.<br>
#     <b style="color:orange">NER can be performed using two Libraries</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">a. NER using NLTK</b><br>
#     &emsp;&emsp;&emsp;<b style="color:gray">b. NER using Spacy</b><br>
# </h3></p>

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">a. NER using NLTK</h3>

# %%
import nltk
stopwords_en=stopwords.words("english")

# %%
sentence="TATA and Mahindra are the top companies in India. But the 'Gautam Adani' and 'Mukesh Ambani' are the reachest person."
words=[word for word in sentence.split(" ") if word not in stopwords_en]
tagged_tokens=nltk.pos_tag(words)
entities=nltk.ne_chunk(tagged_tokens)
for entity in entities:
    print(entity)
# Out:
# (ORGANIZATION TATA/NNP Mahindra/NNP)
# ('top', 'JJ')
# ('companies', 'NNS')
# ('India.', 'NNP')
# ('But', 'CC')
# ("'Gautam", 'NNP')
# ("Adani'", 'NNP')
# ("'Mukesh", 'POS')
# ("Ambani'", 'NNP')
# ('reachest', 'NN')
# ('person.', 'NN')

# %% [markdown]
# <h3 style="color:blue; background:pink; line-height:1">b. NER using Spacy</h3>

# %%
nlp = spacy.load("en_core_web_sm")
sentence="TATA and Mahindra are the top companies in India. But the 'Gautam Adani' and 'Mukesh Ambani' are the reachest person."
doc = nlp(sentence)
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# TATA ORG
# Mahindra ORG
# India GPE
# Gautam Adani' PERSON
# Mukesh Ambani' PERSON

# %% [markdown]
# **<code style="color:green">Spacy is a faster and more efficient library for NER. It provides a pre-trained NER model that is highly accurate than NLTK and can recognize a wide range of named entities. Additionally, SpaCy has more advanced features such as named entity linking and coreference resolution.</code>**

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Text to Numerical Vector Conversion Techniques *</h1>

# %% [markdown]
# <p><h3 style="color:gray; line-height:1.2">Our Machine Learning and Deep Learning models take only numerical data as an input to train the model and do prediction, Hence it is necessary to perform conversion step to make texual data into equivalent numerical representation. There are many text to numerical vector conversion techniques, these techniques are,</h3></p>
# <h3 style="color:gray; line-height:1.2"><b style="color:orange">1. BOW(Bag Of Word): Count Vectorizer</b><br>
# <b style="color:orange">2. TF-IDF(Term Frequence-Inverse Document Frequency)</b><br>
# <b style="color:orange">3. Word2Vec(Word to Vector)</b><br>
# <b style="color:orange">4. GloVe(Global Vector)</b><br>
# <b style="color:orange">5. BERT(Bidirectional Encoder Representations from Transformers) </b></h3>

# %% [markdown]
# <p><h2 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">1. Bag Of Word(Count Vectorizer)</h2>
# <h3 style=" color:gray; line-height:1.3">It is a Collection of words represent a sentence with word count. Steps invloved in this process are Clean Text, Tookenize, Build Vocabulary and Generate Vecors. We can create vocabulory of size 1 to n using uni-ngram, bi-gram, n-gram.<br>
# <b style="color:orange">Advantages:</b><br>
#     &emsp;&emsp; a. Simple Procedure and easy to implement.<br>
#     &emsp;&emsp; b. Easy to Understand<br>
# <b style="color:orange">Disadvantages:</b><br>
#     &emsp;&emsp; a. Does not consider the symmentic meaning of the word.<br>
#     &emsp;&emsp; b. Due to large vector size computational time is high.<br>
#     &emsp;&emsp; c. Count Vectorizer Generates Spars matrix.<br>
#     &emsp;&emsp; d. Out of Vocabulary words are not captured.</h3><p>

# %% [markdown]
# <p><h2 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">2. TF-IDF(Term Frequence-Inverse Document Frequency)</h2>
# <h3 style=" color:gray; line-height:1.3">It is a Statistical method. It measures how important a term or word is within a document or setence relative to a collection of documents or Corpus. Words within a text document are transformed into importance numbers by a text vectorization process.<br>
# <b style="color:orange">Advantages:</b><br>
#     &emsp;&emsp; a. Simple Procedure and easy to implement.<br>
#     &emsp;&emsp; b. Easy to Understand<br>
#     &emsp;&emsp; c. Here unlike BOW, weightage for those words is given high if that word occuring in that document but occuring less in corpus.<br>
# <b style="color:orange">Disadvantages:</b><br>
#     &emsp;&emsp; a. Does not consider the symmentic meaning of the word.<br>
#     &emsp;&emsp; b. Due to large vector size computational time is high.<br>
#     &emsp;&emsp; c. Count Vectorizer Generates Spars matrix.<br>
#     &emsp;&emsp; d. Out of Vocabulary words are not captured.</h3><p>

# %% [markdown]
# <h2 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">3. Word2Vec(Word to Vector)</h2>
# <h3 style=" color:gray; line-height:1.3">It is a pre-trained word embedded model. Word2Vec creates vectors of the words that are distributed numerical representations of word features. These word features represents the context for the each words present in vocabulary. Two different model architectures that can be used by Word2Vec to create the word embeddings are the Continuous Bag of Words (CBOW) model(Used when dataset is small) & the Skip-Gram model(Used when the dataset is large).<br>
# <b style="color:orange">Advantages:</b><br>
#     &emsp;&emsp; a. Word embeddings eventually help in establishing the association of a word with another similar meaning word through the created vectors.<br>
#     &emsp;&emsp; b. Captures symmantic meaning.<br>
#     &emsp;&emsp; c. Low Dimensional vectors hence the computational time reduces.<br>
#     &emsp;&emsp; d. Dense vectors.<br>
# <b style="color:orange">Disadvantages:</b><br>
#     &emsp;&emsp; a. Contexual meaning only captured within the window size. or in other word it has local context scope.<br>
#     &emsp;&emsp; b. Not able to generate vectors for unseen words.</h3><p>

# %% [markdown]
# <h2 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">4. GloVe(Global Vector)</h2>
# <h3 style=" color:gray; line-height:1.3">It is also a Pre-trained word embedding technique used to overcome drawback of Word2Vec. <br>
# <b style="color:orange">Advantages:</b><br>
#     &emsp;&emsp; a. Contexual meaning captured for both local and global scope.<br>
#     &emsp;&emsp; b. It uses co-occurance matrix to tell us how often two words occuring together.<br>
#     &emsp;&emsp; c. Captures symmantic meaning.<br>
#     &emsp;&emsp; d. Low Dimensional vectors hence the computational time reduces.<br>
#     &emsp;&emsp; e. Dense vectors.<br>
# <b style="color:orange">Disadvantages:</b><br>
#     &emsp;&emsp; a. Utilizes massive memory and takes time to load.<br></h3><p>

# %% [markdown]
# <h2 style="background:pink; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">5. BERT(Bidirectional Encoder Representations from Transformers)</h2>
# <h3 style=" color:gray; line-height:1.3">BERT is the Pre-trained birectional trasformer for Language understanding. It has trained on 2500M Wikipedia words and 800M+ Books words. And BERT used by Google search Engine. BERT uses the encoder part of the Transformer, since it’s goal is to create a model that performs a number of different NLP tasks.<br>
# <b style="color:orange">Advantages:</b><br>
#     &emsp;&emsp; a. Contexual meaning captured for both local and global scope.<br>
#     &emsp;&emsp; b. Captures symmantic meaning.<br>
#     &emsp;&emsp; c. Powerful than all previous wod embedding techniques.<br>
# <b style="color:orange">Disadvantages:</b><br>
#     &emsp;&emsp; a. Utilizes massive memory and takes time to load and train.<br></h3><p>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Algorithms Used in Project *</h1>

# %% [markdown]
# <h3 style="color:gray; line-height:1.2"><b style="color:orange">1. Machine Learning Base learner classification models</b><br>
#     &emsp;&emsp; a. Logistic Regression.<br>
#     &emsp;&emsp; b. K-Neighbors classifier.<br>
#     &emsp;&emsp; c. Support Vector Machine.<br>
#     &emsp;&emsp; d. Decision Tree Classifier.<br>
#     &emsp;&emsp; e. Naive Bayes.<br>
# <b style="color:orange">2. Ensemble Methods</b><br>
#     &emsp;&emsp; a. Boosting.<br>
#          &emsp;&emsp;&emsp;&emsp; i.   Ada Boost Classifier.<br>
#          &emsp;&emsp;&emsp;&emsp; ii.  Gradient Boosting Classifier.<br>
#          &emsp;&emsp;&emsp;&emsp; iii. XG Boost Classifier.<br>
#     &emsp;&emsp; b. Bagging.<br>
#          &emsp;&emsp;&emsp;&emsp; i. Random Forest.<br>
# <b style="color:orange">3. Deep Learning Algorithms</b><br>
#     &emsp;&emsp; a. Simple RNN.<br>
#     &emsp;&emsp; b. LSTM.<br>
# <b style="color:orange">4. Siamese Neural Network</b></h3>

# %% [markdown]
# <h1 style="background:lightblue; color:blue; line-height:3; text-align:center; font-family:Arial Black">* Approaches or Methods Used In Project *</h1>

# %% [markdown]
# <h3 style="color:green; line-height:1.5">1. Basic Approach with No Preprocessing of text and using BOW<br>
#                                          2. Basic Approach with Preprocessed data and using BOW and TF-IDF<br>
#                                          3. Advance Approach with Extracted Features and using BOW and TF-IDF<br>
#                                          4. Advance Approach with Own Word Emebeding Techniques.<br>
#                                          5. Advance Approach with Pre-trained Models(Transfer Learning).<br>
#                                          6. Advance Approach using Siamese Neural Network.</h3>

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+ +---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h1 style="background:pink; color:blue; line-height:2.2; text-align:center; font-family:Arial Black">Import Basic Required Libraries</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1 style="background:pink; color:blue; line-height:2.2; text-align:center; font-family:Arial Black">Load the Dataset</h1>

# %%
df=pd.read_csv('data/train.csv')
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %% [markdown]
# <h1 style="background:pink; color:blue; line-height:2.2; text-align:center; font-family:Arial Black">Understanding the Dataset</h1>

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; text-align:left; font-family:Arial Black">1. Shape of Dataset</h3>

# %%
print("Shape of dataset:{}\nNumber of Columns:{}\nNumber of Rows:{}".format(df.shape,df.shape[1],df.shape[0]))
# Out:
# Shape of dataset:(404290, 6)
# Number of Columns:6
# Number of Rows:404290

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; text-align:left; font-family:Arial Black">2. Columns in Dataset</h3>

# %%
print("Total Number of Columns:{}\nColumns are:{}".format(len(df.columns), df.columns))
# Out:
# Total Number of Columns:6
# Columns are:Index(['id', 'qid1', 'qid2', 'question1', 'question2', 'is_duplicate'], dtype='object')

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; text-align:left; font-family:Arial Black">3. Data Types of Column</h3>

# %%
df.dtypes
# Out:
# id               int64
# qid1             int64
# qid2             int64
# question1       object
# question2       object
# is_duplicate     int64
# dtype: object

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; text-align:left; font-family:Arial Black">4. Column Information</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; text-align:left; font-family:Arial Black">5. Missing Values</h3>

# %%
df.isna().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %% [markdown]
# **<code style="color:green">There is 1 Missing value in `Question1` and 2 Missing values in `Question2`. Lets check these row and decide whether to drop these rows or fill with some suitable value.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">6. Missing value Treatment</h3>

# %%
df[df['question2'].isna()]
# Out:
#             id    qid1    qid2                         question1 question2  \
# 105780  105780  174363  174364    How can I develop android app?       NaN
# 201841  201841  303951  174364  How can I create an Android app?       NaN
#
#         is_duplicate
# 105780             0
# 201841             0

# %%
df[df['question1'].isna()]
# Out:
#             id    qid1    qid2 question1  \
# 363362  363362  493340  493341       NaN
#
#                                                 question2  is_duplicate
# 363362  My Chinese name is Haichao Yu. What English na...             0

# %% [markdown]
# **<code style="color:green">We Cannot compute these missing rows with any suitable value, hence it is better to drop these rows.</code>**

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64

# %% [markdown]
# **<code style="color:green">Now we don't have any Missing values in Dataset</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">7. Duplicate Rows</h3>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **<code style="color:green">No Duplicate rows in Dataset</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">8. Data Imbalanace check</h3>

# %%
class_balance=pd.DataFrame(df['is_duplicate'].value_counts()).reset_index()
class_balance.columns=["Class", "Count"]
class_balance['Percentage']=((class_balance['Count']/df.shape[0])*100).round(2)
class_balance
# Out:
#    Class   Count  Percentage
# 0      0  255024       63.08
# 1      1  149263       36.92

# %% [markdown]
# **<code style="color:green">63% Rows are Non-Duplicates and 37% are duplicate. SO we can say that there is no exactly class imbalance.</code>**

# %% [markdown]
# <h1 style="background:pink; color:blue; text-align:center; line-height:2.2; font-family:Arial Black">Selecting Useful Columns</h1>

# %%
data=df[['question1','question2','is_duplicate']]
pd.options.display.max_colwidth=1000
data.head()
# Out:
#                                                                       question1  \
# 0            What is the step by step guide to invest in share market in india?
# 1                           What is the story of Kohinoor (Koh-i-Noor) Diamond?
# 2     How can I increase the speed of my internet connection while using a VPN?
# 3                            Why am I mentally very lonely? How can I solve it?
# 4  Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?
#
#                                                                                   question2  \
# 0                                 What is the step by step guide to invest in share market?
# 1  What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) diamond back?
# 2                               How can Internet speed be increased by hacking through DNS?
# 3                         Find the remainder when [math]23^{24}[/math] is divided by 24,23?
# ...

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Selecting 50000 Sample rows due to less computational power 😶</h3>

# %%
sample=data.sample(50000, random_state=0, ignore_index=True)
sample.head()
# Out:
#                                                                                                                      question1  \
# 0                                                               What are some differences between German and Austrian culture?
# 1                                                                                       What are the best Doctor Doom stories?
# 2                                                                                  What are the best books to prepare for SSB?
# 3  Is an MS in VLSI from Portland State University good? I have heard Intel has a research center on its campus, is that true?
# 4                                                                         Height: How would a 14 year old increase his height?
#
#                                                           question2  \
# 0    What are the cultural differences between Austria and Germany?
# 1                   What are the best comics featuring Doctor Doom?
# ...

# %%
sample.shape
# Out:
# (50000, 3)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Exploratory Data Analysis</h3>

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1; font-family:Arial Black; text-align:left">1. Data Imbalance Check</h3>

# %%
class_balance=pd.DataFrame(sample['is_duplicate'].value_counts()).reset_index()
class_balance.columns=["Class", "Count"]
class_balance['Percentage']=(class_balance['Count']/sample.shape[0])*100
class_balance
# Out:
#    Class  Count  Percentage
# 0      0  31670       63.34
# 1      1  18330       36.66

# %%
label=['Non-Duplicate', 'Duplicate'] 
color=sns.color_palette('rainbow')[4:6]
plt.figure(figsize=(6,6))
plt.pie(x=class_balance['Count'], labels=label, colors=color, autopct='%.0f%%' , labeldistance=0.5)
plt.title("Count of Non-Duplicate and Duplicate questions", fontsize=18, color='green');

# %% [markdown]
# **<code style="color:green">No Strict class Imbalance.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1; font-family:Arial Black; text-align:left">2. Count of Repeating and Non-repeating questions</h3>

# %%
questions=pd.Series(list(sample['question1'])+list(sample['question2']))
tot_que=questions.shape[0]
print("Total Question=", tot_que)
non_rep=np.unique(questions).shape[0]
print("Non-Repeating Question=", non_rep)
rep=questions.value_counts()>1
rep=rep[rep].shape[0]
print("Repeating Questions=", rep)
# Out:
# Total Question= 100000
# Non-Repeating Question= 89027
# Repeating Questions= 7340

# %%
data=[89027,7340]
label=['Non-Repeating', 'Repeating'] 
color=sns.color_palette('rainbow')[4:6]
plt.figure(figsize=(6,6))
plt.pie(x=data, labels=label, colors=color, autopct='%.0f%%' , labeldistance=0.2)
plt.title("Count of Repeating and Non-Repeating questions", fontsize=18, color='green');

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1; font-family:Arial Black; text-align:left">3. Histogram for Question count</h3>

# %%
plt.figure(figsize=(12,5))
plt.hist(questions.value_counts().values, color='pink')
plt.title("Count of questions", fontsize=18, color='green');

# %% [markdown]
# **<code style="color:green;">92% questions are Non-repeating and 8% are repeating.</code>**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+ +---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h1 style="background:pink; color:black; text-align:center; line-height:2.2; font-family:Arial Black">Simple Approach to solve this problem without applying any advanced text preprocessing</h1>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Merge Question1 and Question2</h3>

# %%
simple_approach=sample.copy()
simple_approach['que1_que2']=simple_approach['question1']+simple_approach['question2']
simple_approach.head()
# Out:
#                                                                                                                      question1  \
# 0                                                               What are some differences between German and Austrian culture?
# 1                                                                                       What are the best Doctor Doom stories?
# 2                                                                                  What are the best books to prepare for SSB?
# 3  Is an MS in VLSI from Portland State University good? I have heard Intel has a research center on its campus, is that true?
# 4                                                                         Height: How would a 14 year old increase his height?
#
#                                                           question2  \
# 0    What are the cultural differences between Austria and Germany?
# 1                   What are the best comics featuring Doctor Doom?
# ...

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Remove Special Characters and Numbers</h3>

# %%
def simple_approach_clean(text):
    text=str(text).lower()
    text=re.sub("[^a-zA-Z]", " ", text)
    return text

simple_approach['clean_que1_que2']=simple_approach['que1_que2'].apply(simple_approach_clean)
simple_approach.head()
# Out:
#                                                                                                                      question1  \
# 0                                                               What are some differences between German and Austrian culture?
# 1                                                                                       What are the best Doctor Doom stories?
# 2                                                                                  What are the best books to prepare for SSB?
# 3  Is an MS in VLSI from Portland State University good? I have heard Intel has a research center on its campus, is that true?
# 4                                                                         Height: How would a 14 year old increase his height?
#
#                                                           question2  \
# 0    What are the cultural differences between Austria and Germany?
# 1                   What are the best comics featuring Doctor Doom?
# ...

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Divide data into Input and output</h3>

# %%
X=simple_approach['clean_que1_que2']
y=simple_approach['is_duplicate']

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Splitting data into training and testing sets</h3>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20, random_state=0)
print("x train shape", x_train.shape)
print("y train shape", y_train.shape)
print("x test shape", x_test.shape)
print("y test shape", y_test.shape)
# Out:
# x train shape (40000,)
# y train shape (40000,)
# x test shape (10000,)
# y test shape (10000,)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Text to Numeric Vector Converasion</h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer
cnt_vect=CountVectorizer(ngram_range=(1,3))
cnt_vect_fit=cnt_vect.fit(x_train)
x_train_tf=cnt_vect_fit.transform(x_train)
x_test_tf=cnt_vect_fit.transform(x_test)

# %%
len(cnt_vect_fit.vocabulary_)
# Out:
# 733330

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Build Machine Learning Classification models and record the experiment using MLFLOW</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Set Experiment</h3>

# %%
import mlflow
mlflow.set_experiment("Simple Approach")
# Out:
# <Experiment: artifact_location='file:///D:/DATA%20SCIENCE%20Internship%20with%20Innomatics/Final_%20Project_Quora_Question_Pair_Similarity/mlruns/564142714860734513', creation_time=1684555539050, experiment_id='564142714860734513', last_update_time=1684555539050, lifecycle_stage='active', name='Simple Approach', tags={}>

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">1. Logistic Regression</h3>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Logistic")
    
    log_regression=LogisticRegression()
    log_regression.fit(x_train_tf,y_train)
    pickle.dump(log_regression, open("resources_simple_approach/logistic_regression.pkl","wb"))
    
    y_pred=log_regression.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_simple_approach/log_reg_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(log_regression, artifact_path="models")
    mlflow.log_artifact("resources_simple_approach/log_reg_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7601
# Precission=0.7115894039735099
# Recall=0.5844438400870274
# F1 Score=0.6417799014484097
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2399 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82      6323
#            1       0.71      0.58      0.64      3677
#
#     accuracy                           0.76     10000
#    macro avg       0.75      0.72      0.73     10000
# weighted avg       0.76      0.76      0.75     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the logistic regression model is 76%. <br>2. Out of total non-duplicate predicted class 78% are accurate and Out of total duplicate predicted class 71% are accurate.<br>3. Out of total actual non-duplicates class 86% are predicted accuractely and Out of total actual duplicates class 58% are predicted accuractely.<br>4. f1 score for non-duplicate class is 82% and for duplicate class is 64%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">2. Decision Tree Classifier</h3>

# %%
from sklearn.tree import DecisionTreeClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Decision Tree")
    
    dt_classifier=DecisionTreeClassifier()
    dt_classifier.fit(x_train_tf,y_train)
    pickle.dump(dt_classifier, open("resources_simple_approach/decision_tree.pkl","wb"))
    
    y_pred=dt_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_simple_approach/decision_tree_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(dt_classifier, artifact_path="models")
    mlflow.log_artifact("resources_simple_approach/decision_tree_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.702
# Precission=0.6027720436449425
# Recall=0.5558879521348926
# F1 Score=0.5783814374646293
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2980 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77      6323
#            1       0.60      0.56      0.58      3677
#
#     accuracy                           0.70     10000
#    macro avg       0.68      0.67      0.67     10000
# weighted avg       0.70      0.70      0.70     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Decision tree classifier is 70%. <br>2. Out of total non-duplicate predicted class 75% are accurate and Out of total duplicate predicted class 60% are accurate.<br>3. Out of total actual non-duplicates class 79% are predicted accuractely and Out of total actual duplicates class 56% are predicted accuractely.<br>4. f1 score for non-duplicate class is 77% and for duplicate class is 58%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">3. Random Forest Classifier</h3>

# %%
from sklearn.ensemble import RandomForestClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Random Forest")
    
    rf_classifier=RandomForestClassifier()
    rf_classifier.fit(x_train_tf,y_train)
    pickle.dump(rf_classifier, open("resources_simple_approach/random_forest.pkl","wb"))
    
    y_pred=rf_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_simple_approach/random_forest_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(rf_classifier, artifact_path="models")
    mlflow.log_artifact("resources_simple_approach/random_forest_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7486
# Precission=0.8214483139856275
# Recall=0.4041338047321186
# F1 Score=0.5417426175720015
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2514 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.73      0.95      0.83      6323
#            1       0.82      0.40      0.54      3677
#
#     accuracy                           0.75     10000
#    macro avg       0.78      0.68      0.68     10000
# weighted avg       0.77      0.75      0.72     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Random Forest Classifier is 75%. <br>2. Out of total non-duplicate predicted class 73% are accurate and Out of total duplicate predicted class 82% are accurate.<br>3. Out of total actual non-duplicates class 95% are predicted accuractely and Out of total actual duplicates class 40% are predicted accuractely.<br>4. f1 score for non-duplicate class is 83% and for duplicate class is 54%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">4. Gradient Boosting Classifier</h3>

# %%
from sklearn.ensemble import GradientBoostingClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Gradient Boost")
    
    gb_classifier=GradientBoostingClassifier()
    gb_classifier.fit(x_train_tf,y_train)
    pickle.dump(gb_classifier, open("resources_simple_approach/gradient_boostig.pkl","wb"))
    
    y_pred=gb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_simple_approach/gradient_boost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(gb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_simple_approach/gradient_boost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7004
# Precission=0.7161904761904762
# Recall=0.30677182485722054
# F1 Score=0.42955064737242954
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2996 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.70      0.93      0.80      6323
#            1       0.72      0.31      0.43      3677
#
#     accuracy                           0.70     10000
#    macro avg       0.71      0.62      0.61     10000
# weighted avg       0.70      0.70      0.66     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Gradient Boosting Classifier is 70%. <br>2. Out of total non-duplicate predicted class 70% are accurate and Out of total duplicate predicted class 72% are accurate.<br>3. Out of total actual non-duplicates class 93% are predicted accuractely and Out of total actual duplicates class 31% are predicted accuractely.<br>4. f1 score for non-duplicate class is 80% and for duplicate class is 43%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">5. Ada Boost Classifier</h3>

# %%
from sklearn.ensemble import AdaBoostClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Ada Boost")
    
    ada_classifier=AdaBoostClassifier()
    ada_classifier.fit(x_train_tf,y_train)
    pickle.dump(ada_classifier, open("resources_simple_approach/ada_boosting.pkl","wb"))
    
    y_pred=ada_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_simple_approach/ada_boost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(ada_classifier, artifact_path="models")
    mlflow.log_artifact("resources_simple_approach/ada_boost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6947
# Precission=0.6381753764393269
# Recall=0.3918955670383465
# F1 Score=0.4855939342881213
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3053 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.71      0.87      0.78      6323
#            1       0.64      0.39      0.49      3677
#
#     accuracy                           0.69     10000
#    macro avg       0.67      0.63      0.63     10000
# weighted avg       0.68      0.69      0.67     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Ada Boost Classifier is 69%. <br>2. Out of total non-duplicate predicted class 71% are accurate and Out of total duplicate predicted class 64% are accurate.<br>3. Out of total actual non-duplicates class 87% are predicted accuractely and Out of total actual duplicates class 39% are predicted accuractely.<br>4. f1 score for non-duplicate class is 78% and for duplicate class is 49%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">6. XG Boost Classifier</h3>

# %%
from xgboost import XGBClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "XG Boost")
    
    xgb_classifier=XGBClassifier()
    xgb_classifier.fit(x_train_tf,y_train)
    pickle.dump(xgb_classifier, open("resources_simple_approach/xgboost.pkl","wb"))
    
    y_pred=xgb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_simple_approach/xgboost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(xgb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_simple_approach/xgboost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7445
# Precission=0.7146136189747513
# Recall=0.5080228447103617
# F1 Score=0.5938642505166111
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2555 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81      6323
#            1       0.71      0.51      0.59      3677
#
#     accuracy                           0.74     10000
#    macro avg       0.73      0.70      0.70     10000
# weighted avg       0.74      0.74      0.73     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the XG Boost Classifier is 74%. <br>2. Out of total non-duplicate predicted class 76% are accurate and Out of total duplicate predicted class 71% are accurate.<br>3. Out of total actual non-duplicates class 88% are predicted accuractely and Out of total actual duplicates class 51% are predicted accuractely.<br>4. f1 score for non-duplicate class is 81% and for duplicate class is 59%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# ### Inference of Basic Approach:
# 1. **Since our target class is not perfectly balanaced, so we cannot evaluate our model just based on Accuracy Score. Here we need to consider both Precision and Recall.**
# 2. **Accuracy is high in Logistic regression model(76%) and also both XGBoost and Random Forest model have accuracy(75%) nearly equal to Logistic regression.**
# 3. **Precission is high(82%) in Random forest.**
# 4. **Recall score is high(59%) in Logistic Regression.**
# 5. **F1 score is high(64%) in Logistic Regression**
# 6. **In the basic approach without doing any text preprocessing "Logistic Regression" model performance is good.**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+ +---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h1 style="background:pink; color:black; text-align:center; line-height:2.2; font-family:Arial Black">Basic Approach to solve this problem using basic Text to Numerical Conversion techniques with preprocessed data</h1>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Create Function for Text Pre-Processing</h3>

# %%
def text_preprocessing(text):
    text=str(text).lower()                                                  #Lowering
    #text=TextBlob(text).correct()                                          #Spelling correction
    text=contractions.fix(str(text))                                        #Expanding Contraction
    text=re.sub("<.*?>", " ", text)                                         #Remove html tags
    text=re.sub("(http|https|www)\S+", " ", text)                           #Remove URLs
    text=re.sub("[^a-zA-Z]", " ", text)                                     #Removing everything except character
    text=re.sub(" +"," ", text)                                             #Remove extra spaces
    text=[word for word in text.split(" ") if word not in stopwords_en]     #Remove Stopwords
    text=" ".join(text)
    text=[lemma.lemmatize(word) for word in text.split(" ")]                #Lemmatization
    #text=" ".join([word for word in text if len(word)>1])                  #word with more than 1 character
    text=" ".join(text)
    return text

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Concate Question1 and Question2 to create one column and then apply Preprocessing step.</h3>

# %%
advance_approach=sample.copy()
advance_approach.head()
# Out:
#                                                                                                                      question1  \
# 0                                                               What are some differences between German and Austrian culture?
# 1                                                                                       What are the best Doctor Doom stories?
# 2                                                                                  What are the best books to prepare for SSB?
# 3  Is an MS in VLSI from Portland State University good? I have heard Intel has a research center on its campus, is that true?
# 4                                                                         Height: How would a 14 year old increase his height?
#
#                                                           question2  \
# 0    What are the cultural differences between Austria and Germany?
# 1                   What are the best comics featuring Doctor Doom?
# ...

# %%
advance_approach['combine_question']=advance_approach['question1']+" "+advance_approach['question2']
advance_approach.head()
# Out:
#                                                                                                                      question1  \
# 0                                                               What are some differences between German and Austrian culture?
# 1                                                                                       What are the best Doctor Doom stories?
# 2                                                                                  What are the best books to prepare for SSB?
# 3  Is an MS in VLSI from Portland State University good? I have heard Intel has a research center on its campus, is that true?
# 4                                                                         Height: How would a 14 year old increase his height?
#
#                                                           question2  \
# 0    What are the cultural differences between Austria and Germany?
# 1                   What are the best comics featuring Doctor Doom?
# ...

# %%
advance_approach.shape
# Out:
# (50000, 4)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Now apply Preprocessing function on  concatenated column (Question1 and Question2) and store the preprocessed questions into new columns.</h3>

# %%
advance_approach['question_clean']=advance_approach['combine_question'].apply(text_preprocessing)
advance_approach.head()
# Out:
#                                                                                                                      question1  \
# 0                                                               What are some differences between German and Austrian culture?
# 1                                                                                       What are the best Doctor Doom stories?
# 2                                                                                  What are the best books to prepare for SSB?
# 3  Is an MS in VLSI from Portland State University good? I have heard Intel has a research center on its campus, is that true?
# 4                                                                         Height: How would a 14 year old increase his height?
#
#                                                           question2  \
# 0    What are the cultural differences between Austria and Germany?
# 1                   What are the best comics featuring Doctor Doom?
# ...

# %%
advance_approach.shape
# Out:
# (50000, 5)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Now We are saving this Preprocessing DataFrame to save preproccesing time.</h3>

# %%
advance_approach.to_csv("data/clean_advance_approach.csv", index=False)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Divide data into Input and output</h3>

# %%
X=advance_approach['question_clean']
y=advance_approach['is_duplicate']

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Splitting data into training and testing sets</h3>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y, test_size=0.2)
print("X train shape=", x_train.shape)
print("X test shape=", x_test.shape)
print("Y train shape=", y_train.shape)
print("Y test shape=", y_test.shape)
# Out:
# X train shape= (40000,)
# X test shape= (10000,)
# Y train shape= (40000,)
# Y test shape= (10000,)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Text to Numeric Vector Converasion</h3>
# <h3 style="background:yellow; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Technique-1 Count Vectorizer</h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer
cnt=CountVectorizer(ngram_range=(1, 3))
cnt_fit=cnt.fit(x_train)
x_train_tf=cnt_fit.transform(x_train)
x_test_tf=cnt_fit.transform(x_test)

# %%
len(cnt_fit.vocabulary_)
# Out:
# 528658

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Built Machine Learning Classification models and record the experiment using MLFLOW</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Set Experiment</h3>

# %%
import mlflow
mlflow.set_experiment("Advance Approach with CountVectorizer")
# Out:
# 2023/05/23 19:22:03 INFO mlflow.tracking.fluent: Experiment with name 'Advance Approach with CountVectorizer' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///D:/DATA%20SCIENCE%20Internship%20with%20Innomatics/Final_%20Project_Quora_Question_Pair_Similarity/mlruns/724245093111104811', creation_time=1684849923735, experiment_id='724245093111104811', last_update_time=1684849923735, lifecycle_stage='active', name='Advance Approach with CountVectorizer', tags={}>

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">1. Logistic Regression</h3>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Logistic")
    
    log_regression=LogisticRegression()
    log_regression.fit(x_train_tf,y_train)
    pickle.dump(log_regression, open("resources_advance_approach_with_CNT_VECT/logistic_regression.pkl","wb"))
    
    y_pred=log_regression.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_CNT_VECT/log_reg_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(log_regression, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_CNT_VECT/log_reg_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7549
# Precission=0.7318681318681318
# Recall=0.5375302663438256
# F1 Score=0.6198231735691019
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2451 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82      6283
#            1       0.73      0.54      0.62      3717
#
#     accuracy                           0.75     10000
#    macro avg       0.75      0.71      0.72     10000
# weighted avg       0.75      0.75      0.75     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Logistic regression is 75%. <br>2. Out of total non-duplicate predicted class 76% are accurate and Out of total duplicate predicted class 73% are accurate.<br>3. Out of total actual non-duplicates class 88% are predicted accuractely and Out of total actual duplicates class 54% are predicted accuractely.<br>4. f1 score for non-duplicate class is 82% and for duplicate class is 62%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">2. Decision Tree Classifier</h3>

# %%
from sklearn.tree import DecisionTreeClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Decision Tree")
    
    dt_classifier=DecisionTreeClassifier()
    dt_classifier.fit(x_train_tf,y_train)
    pickle.dump(dt_classifier, open("resources_advance_approach_with_CNT_VECT/decision_tree.pkl","wb"))
    
    y_pred=dt_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_CNT_VECT/decision_tree_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(dt_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_CNT_VECT/decision_tree_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.726
# Precission=0.6570234651237544
# Recall=0.5499058380414312
# F1 Score=0.5987111892208554
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2740 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79      6283
#            1       0.66      0.55      0.60      3717
#
#     accuracy                           0.73     10000
#    macro avg       0.71      0.69      0.70     10000
# weighted avg       0.72      0.73      0.72     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Decision Tree Classifier is 73%. <br>2. Out of total non-duplicate predicted class 76% are accurate and Out of total duplicate predicted class 66% are accurate.<br>3. Out of total actual non-duplicates class 83% are predicted accuractely and Out of total actual duplicates class 55% are predicted accuractely.<br>4. f1 score for non-duplicate class is 79% and for duplicate class is 60%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">3. Random Forest Classifier</h3>

# %%
from sklearn.ensemble import RandomForestClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Random Forest")
    
    rf_classifier=RandomForestClassifier()
    rf_classifier.fit(x_train_tf,y_train)
    pickle.dump(rf_classifier, open("resources_advance_approach_with_CNT_VECT/random_forest.pkl","wb"))
    
    y_pred=rf_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_CNT_VECT/random_forest_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(rf_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_CNT_VECT/random_forest_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7551
# Precission=0.7825311942959001
# Recall=0.47242399784772665
# F1 Score=0.5891628921321925
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2449 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83      6283
#            1       0.78      0.47      0.59      3717
#
#     accuracy                           0.76     10000
#    macro avg       0.76      0.70      0.71     10000
# weighted avg       0.76      0.76      0.74     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Random Forest Classifier is 76%. <br>2. Out of total non-duplicate predicted class 75% are accurate and Out of total duplicate predicted class 78% are accurate.<br>3. Out of total actual non-duplicates class 92% are predicted accuractely and Out of total actual duplicates class 47% are predicted accuractely.<br>4. f1 score for non-duplicate class is 83% and for duplicate class is 59%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">4. Gradient Boosting Classifier</h3>

# %%
from sklearn.ensemble import GradientBoostingClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Gradient Boost")
    
    gb_classifier=GradientBoostingClassifier()
    gb_classifier.fit(x_train_tf,y_train)
    pickle.dump(gb_classifier, open("resources_advance_approach_with_CNT_VECT/gradient_boostig.pkl","wb"))
    
    y_pred=gb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_CNT_VECT/gradient_boost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(gb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_CNT_VECT/gradient_boost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6805
# Precission=0.7952488687782805
# Recall=0.18913101963949422
# F1 Score=0.30558574222995
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3195 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.67      0.97      0.79      6283
#            1       0.80      0.19      0.31      3717
#
#     accuracy                           0.68     10000
#    macro avg       0.73      0.58      0.55     10000
# weighted avg       0.72      0.68      0.61     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Gradient Boosting Classifier is 68%. <br>2. Out of total non-duplicate predicted class 67% are accurate and Out of total duplicate predicted class 80% are accurate.<br>3. Out of total actual non-duplicates class 97% are predicted accuractely and Out of total actual duplicates class 19% are predicted accuractely.<br>4. f1 score for non-duplicate class is 79% and for duplicate class is 31%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">5. Ada Boost Classifier</h3>

# %%
from sklearn.ensemble import AdaBoostClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Ada Boost")
    
    ada_classifier=AdaBoostClassifier()
    ada_classifier.fit(x_train_tf,y_train)
    pickle.dump(ada_classifier, open("resources_advance_approach_with_CNT_VECT/ada_boosting.pkl","wb"))
    
    y_pred=ada_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_CNT_VECT/ada_boost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(ada_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_CNT_VECT/ada_boost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6838
# Precission=0.6595744680851063
# Recall=0.30858218993812214
# F1 Score=0.42045454545454547
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3162 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.69      0.91      0.78      6283
#            1       0.66      0.31      0.42      3717
#
#     accuracy                           0.68     10000
#    macro avg       0.67      0.61      0.60     10000
# weighted avg       0.68      0.68      0.65     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the XG Boost Classifier is 68%. <br>2. Out of total non-duplicate predicted class 69% are accurate and Out of total duplicate predicted class 66% are accurate.<br>3. Out of total actual non-duplicates class 91% are predicted accuractely and Out of total actual duplicates class 31% are predicted accuractely.<br>4. f1 score for non-duplicate class is 78% and for duplicate class is 42%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">6. XG Boost Classifier</h3>

# %%
from xgboost import XGBClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "XG Boost")
    
    xgb_classifier=XGBClassifier()
    xgb_classifier.fit(x_train_tf,y_train)
    pickle.dump(xgb_classifier, open("resources_advance_approach_with_CNT_VECT/xgboost.pkl","wb"))
    
    y_pred=xgb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_CNT_VECT/xgboost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(xgb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_CNT_VECT/xgboost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7207
# Precission=0.7746730083234245
# Recall=0.35055152004304546
# F1 Score=0.4826819781441008
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2793 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.71      0.94      0.81      6283
#            1       0.77      0.35      0.48      3717
#
#     accuracy                           0.72     10000
#    macro avg       0.74      0.65      0.65     10000
# weighted avg       0.73      0.72      0.69     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the XG Boost Classifier is 72%. <br>2. Out of total non-duplicate predicted class 71% are accurate and Out of total duplicate predicted class 77% are accurate.<br>3. Out of total actual non-duplicates class 94% are predicted accuractely and Out of total actual duplicates class 35% are predicted accuractely.<br>4. f1 score for non-duplicate class is 81% and for duplicate class is 48%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# ### Inference Basic Approach with Count Vectorizer:
# 1. **Accuracy is high(76%) in both Logistic regression and Random Forest.**
# 2. **Precission is high(79%) in Gradient Boost.**
# 3. **Recall score is high(55%) in Decision Tree.**
# 4. **F1 score is high(62%) in Logistic Regression**
# 5. **In the advance approach after doing text preprocesing and using Count vectorizer the "Logistic Regression" model performance is good.**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Technique-2 TF-IDF Vectorizer</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Text to numerical conversion using TF-IDF</h3>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(ngram_range=(1, 3))
tfidf_fit=tfidf.fit(x_train)
x_train_tf=tfidf_fit.transform(x_train)
x_test_tf=tfidf_fit.transform(x_test)

# %%
len(tfidf_fit.vocabulary_)
# Out:
# 529424

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Built Machine Learning Classification models and record the experiment using MLFLOW</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Set Experiment</h3>

# %%
import mlflow
mlflow.set_experiment("Advance Approach with TF-IDF")
# Out:
# 2023/05/24 10:22:47 INFO mlflow.tracking.fluent: Experiment with name 'Advance Approach with TF-IDF' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///D:/DATA%20SCIENCE%20Internship%20with%20Innomatics/Final_%20Project_Quora_Question_Pair_Similarity/mlruns/924901483531188997', creation_time=1684903967571, experiment_id='924901483531188997', last_update_time=1684903967571, lifecycle_stage='active', name='Advance Approach with TF-IDF', tags={}>

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">1. Logistic Regression</h3>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Logistic")
    
    log_regression=LogisticRegression()
    log_regression.fit(x_train_tf,y_train)
    pickle.dump(log_regression, open("resources_advance_approach_with_TFIDF/logistic_regression.pkl","wb"))
    
    y_pred=log_regression.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix(=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_TFIDF/log_reg_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(log_regression, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_TFIDF/log_reg_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7371
# Precission=0.7168316831683168
# Recall=0.48603651987110635
# F1 Score=0.5792926868298929
# ----------------------------------------------------------
# Confusion Matrix(=
# ----------------------------------------------------------
# Out of 10000 testing values 2629 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81      6276
#            1       0.72      0.49      0.58      3724
#
#     accuracy                           0.74     10000
#    macro avg       0.73      0.69      0.69     10000
# weighted avg       0.73      0.74      0.72     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Logistic Regression is 74%. <br>2. Out of total non-duplicate predicted class 74% are accurate and Out of total duplicate predicted class 72% are accurate.<br>3. Out of total actual non-duplicates class 89% are predicted accuractely and Out of total actual duplicates class 49% are predicted accuractely.<br>4. f1 score for non-duplicate class is 81% and for duplicate class is 58%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">2. Decision Tree Classifier</h3>

# %%
from sklearn.tree import DecisionTreeClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Decision Tree")
    
    dt_classifier=DecisionTreeClassifier()
    dt_classifier.fit(x_train_tf,y_train)
    pickle.dump(dt_classifier, open("resources_advance_approach_with_TFIDF/decision_tree.pkl","wb"))
    
    y_pred=dt_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_TFIDF/decision_tree_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(dt_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_TFIDF/decision_tree_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6393
# Precission=0.5129453418897987
# Recall=0.6224489795918368
# F1 Score=0.5624165958995512
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3607 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.74      0.65      0.69      6276
#            1       0.51      0.62      0.56      3724
#
#     accuracy                           0.64     10000
#    macro avg       0.63      0.64      0.63     10000
# weighted avg       0.66      0.64      0.64     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Decision Tree Classifier is 64%. <br>2. Out of total non-duplicate predicted class 74% are accurate and Out of total duplicate predicted class 51% are accurate.<br>3. Out of total actual non-duplicates class 65% are predicted accuractely and Out of total actual duplicates class 62% are predicted accuractely.<br>4. f1 score for non-duplicate class is 69% and for duplicate class is 56%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">3. Random Forest Classifier</h3>

# %%
from sklearn.ensemble import RandomForestClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Random Forest")
    
    rf_classifier=RandomForestClassifier()
    rf_classifier.fit(x_train_tf,y_train)
    pickle.dump(rf_classifier, open("resources_advance_approach_with_TFIDF/random_forest.pkl","wb"))
    
    y_pred=rf_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_TFIDF/random_forest_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(rf_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_TFIDF/random_forest_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7338
# Precission=0.6570076877587226
# Recall=0.5966702470461869
# F1 Score=0.6253869969040247
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2662 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79      6276
#            1       0.66      0.60      0.63      3724
#
#     accuracy                           0.73     10000
#    macro avg       0.72      0.71      0.71     10000
# weighted avg       0.73      0.73      0.73     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Random Forest Classifier is 73%. <br>2. Out of total non-duplicate predicted class 77% are accurate and Out of total duplicate predicted class 66% are accurate.<br>3. Out of total actual non-duplicates class 82% are predicted accuractely and Out of total actual duplicates class 60% are predicted accuractely.<br>4. f1 score for non-duplicate class is 79% and for duplicate class is 63%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">4. Gradient Boosting Classifier</h3>

# %%
from sklearn.ensemble import GradientBoostingClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Gradient Boost")
    
    gb_classifier=GradientBoostingClassifier()
    gb_classifier.fit(x_train_tf,y_train)
    pickle.dump(gb_classifier, open("resources_advance_approach_with_TFIDF/gradient_boostig.pkl","wb"))
    
    y_pred=gb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_TFIDF/gradient_boost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(gb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_TFIDF/gradient_boost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6781
# Precission=0.6465467208357516
# Recall=0.299140708915145
# F1 Score=0.40903249495134936
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3219 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.68      0.90      0.78      6276
#            1       0.65      0.30      0.41      3724
#
#     accuracy                           0.68     10000
#    macro avg       0.67      0.60      0.59     10000
# weighted avg       0.67      0.68      0.64     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Gradient Boost Classifier is 68%. <br>2. Out of total non-duplicate predicted class 68% are accurate and Out of total duplicate predicted class 65% are accurate.<br>3. Out of total actual non-duplicates class 90% are predicted accuractely and Out of total actual duplicates class 30% are predicted accuractely.<br>4. f1 score for non-duplicate class is 78% and for duplicate class is 41%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">5. Ada Boost Classifier</h3>

# %%
from sklearn.ensemble import AdaBoostClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Ada Boost")
    
    ada_classifier=AdaBoostClassifier()
    ada_classifier.fit(x_train_tf,y_train)
    pickle.dump(ada_classifier, open("resources_advance_approach_with_TFIDF/ada_boosting.pkl","wb"))
    
    y_pred=ada_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_TFIDF/ada_boost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(ada_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_TFIDF/ada_boost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6683
# Precission=0.5886710239651416
# Recall=0.36278195488721804
# F1 Score=0.4489117793653431
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3317 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.69      0.85      0.76      6276
#            1       0.59      0.36      0.45      3724
#
#     accuracy                           0.67     10000
#    macro avg       0.64      0.61      0.61     10000
# weighted avg       0.65      0.67      0.65     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Ada Boost Classifier is 67%. <br>2. Out of total non-duplicate predicted class 69% are accurate and Out of total duplicate predicted class 59% are accurate.<br>3. Out of total actual non-duplicates class 85% are predicted accuractely and Out of total actual duplicates class 36% are predicted accuractely.<br>4. f1 score for non-duplicate class is 76% and for duplicate class is 45%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">6. XG Boost Classifier</h3>

# %%
from xgboost import XGBClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "XG Boost")
    
    xgb_classifier=XGBClassifier()
    xgb_classifier.fit(x_train_tf,y_train)
    pickle.dump(xgb_classifier, open("resources_advance_approach_with_TFIDF/xgboost.pkl","wb"))
    
    y_pred=xgb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_with_TFIDF/xgboost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(xgb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_with_TFIDF/xgboost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.682
# Precission=0.5891218872870249
# Recall=0.48281417830290013
# F1 Score=0.5306965761511215
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3180 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.72      0.80      0.76      6276
#            1       0.59      0.48      0.53      3724
#
#     accuracy                           0.68     10000
#    macro avg       0.66      0.64      0.65     10000
# weighted avg       0.67      0.68      0.67     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the XG Boost Classifier is 68%. <br>2. Out of total non-duplicate predicted class 72% are accurate and Out of total duplicate predicted class 59% are accurate.<br>3. Out of total actual non-duplicates class 80% are predicted accuractely and Out of total actual duplicates class 48% are predicted accuractely.<br>4. f1 score for non-duplicate class is 76% and for duplicate class is 53%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# ### Inference of Basic Approach with TFIDF Vectorizer:
# 1. **Accuracy is high(74%) in both Logistic regression and Random Forest.**
# 2. **Precission is high(79%) in Logistic Regression.**
# 3. **Recall score is high(62%) in Decision Tree.**
# 4. **F1 score is high(63%) in Random Forest**
# 5. **In the advance approach after doing text preprocesing and using TFIDF vectorizer the "Random Forest Classifier" model performance is good.**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+ +---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h1 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:center;">Running Naive Bayes, Support vector and K-Nearest Neighbors classifier for small sample of data</h1>
# <h3 style="color:gray;">Naive Bayes required "Dense Array or Matrix" to train the model. Support vector machine required huge time to train on data hence it is better to train these models using small sample of data.</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Take smaller sample of data</h3>

# %%
small_sample=advance_approach.sample(5000, ignore_index=True, random_state=0)
small_sample.head()
# Out:
#                                                                                       question1  \
# 0                                                      From where can I get a Reliance Jio SIM?
# 1                                                              Can you get the same cold twice?
# 2  What is the meaning of word "Chaiyya" in the Song "Chaiyya Chaiyya" From the movie "Dil Se"?
# 3                                   What is the best photo you have taken with your cell phone?
# 4                                                Does a long distance relationship really work?
#
#                                                              question2  \
# 0                                     Should I buy a Reliance Jio sim?
# 1                   Can one have two different colds at the same time?
# 2  What is the meaning of song Jimmy, Renda-se by Tom Zé (in english)?
# 3        What are some of the best pictures taken with a phone camera?
# ...

# %%
small_sample.shape
# Out:
# (5000, 5)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Class Imbalance check</h3>

# %%
class_imbalance=pd.DataFrame(small_sample['is_duplicate'].value_counts()).reset_index()
class_imbalance.columns=["Class", "Count"]
class_imbalance['Percentage']=(class_imbalance['Count']/small_sample.shape[0])*100
class_imbalance
# Out:
#    Class  Count  Percentage
# 0      0   3164       63.28
# 1      1   1836       36.72

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Divide data into input and output</h3>

# %%
X=small_sample['question_clean']
y=small_sample['is_duplicate']

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Train test split</h3>

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y, test_size=0.2)
print("X train shape=", x_train.shape)
print("X test shape=", x_test.shape)
print("Y train shape=", y_train.shape)
print("Y test shape=", y_test.shape)
# Out:
# X train shape= (4000,)
# X test shape= (1000,)
# Y train shape= (4000,)
# Y test shape= (1000,)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Text to numeric conversion</h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer
cnt=CountVectorizer(ngram_range=(1, 3))
cnt_fit=cnt.fit(x_train)
x_train_tf=cnt_fit.transform(x_train).toarray()
x_test_tf=cnt_fit.transform(x_test).toarray()

# %%
len(cnt_fit.vocabulary_)
# Out:
# 69273

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Build machine learning model and record experiment</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Set Experiment</h3>

# %%
mlflow.set_experiment("Special Cases")
# Out:
# <Experiment: artifact_location='file:///D:/DATA%20SCIENCE%20Internship%20with%20Innomatics/Final_%20Project_Quora_Question_Pair_Similarity/mlruns/417845609732181399', creation_time=1684918304211, experiment_id='417845609732181399', last_update_time=1684918304211, lifecycle_stage='active', name='Special Cases', tags={}>

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">1. Naive Bayes Algorithm</h3>

# %%
from sklearn.naive_bayes import GaussianNB
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Naive Bayes")
    
    naive_classifier=GaussianNB()
    naive_classifier.fit(x_train_tf,y_train)
    pickle.dump(naive_classifier, open("resources_special _cases/naive.pkl","wb"))
    
    y_pred=naive_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_special _cases/naive_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(naive_classifier, artifact_path="models")
    mlflow.log_artifact("resources_special _cases/naive_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.663
# Precission=0.5256410256410257
# Recall=0.5742296918767507
# F1 Score=0.5488621151271753
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 1000 testing values 337 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73       643
#            1       0.53      0.57      0.55       357
#
#     accuracy                           0.66      1000
#    macro avg       0.64      0.64      0.64      1000
# weighted avg       0.67      0.66      0.67      1000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Naive Bayes is 66%. <br>2. Out of total non-duplicate predicted class 75% are accurate and Out of total duplicate predicted class 53% are accurate.<br>3. Out of total actual non-duplicates class 71% are predicted accuractely and Out of total actual duplicates class 57% are predicted accuractely.<br>4. f1 score for non-duplicate class is 73% and for duplicate class is 55%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">2. Support vector Classifier</h3>

# %%
from sklearn.svm import SVC
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "SVM")
    
    svm_classifier=SVC()
    svm_classifier.fit(x_train_tf,y_train)
    pickle.dump(svm_classifier, open("resources_special _cases/svm.pkl","wb"))
    
    y_pred=svm_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_special _cases/svm_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(svm_classifier, artifact_path="models")
    mlflow.log_artifact("resources_special _cases/svm_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.711
# Precission=0.7098765432098766
# Recall=0.32212885154061627
# F1 Score=0.4431599229287091
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 1000 testing values 289 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.71      0.93      0.80       643
#            1       0.71      0.32      0.44       357
#
#     accuracy                           0.71      1000
#    macro avg       0.71      0.62      0.62      1000
# weighted avg       0.71      0.71      0.68      1000
#
# ----------------------------------------------------------
# ...

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Support vector machine Classifier is 71%. <br>2. Out of total non-duplicate predicted class 71% are accurate and Out of total duplicate predicted class 71% are accurate.<br>3. Out of total actual non-duplicates class 93% are predicted accuractely and Out of total actual duplicates class 32% are predicted accuractely.<br>4. f1 score for non-duplicate class is 80% and for duplicate class is 44%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">3. K-Nearest Neighbors Classifier</h3>

# %%
from sklearn.neighbors import KNeighborsClassifier
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "KNN")
    
    knn_classifier=KNeighborsClassifier()
    knn_classifier.fit(x_train_tf,y_train)
    pickle.dump(knn_classifier, open("resources_special _cases/knn.pkl","wb"))
    
    y_pred=knn_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_special _cases/knn_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(knn_classifier, artifact_path="models")
    mlflow.log_artifact("resources_special _cases/knn_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.693
# Precission=0.7717391304347826
# Recall=0.19887955182072828
# F1 Score=0.31625835189309576
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 1000 testing values 307 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.69      0.97      0.80       643
#            1       0.77      0.20      0.32       357
#
#     accuracy                           0.69      1000
#    macro avg       0.73      0.58      0.56      1000
# weighted avg       0.72      0.69      0.63      1000
#
# ----------------------------------------------------------
# ...

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the KNN Classifier is 69%. <br>2. Out of total non-duplicate predicted class 69% are accurate and Out of total duplicate predicted class 77% are accurate.<br>3. Out of total actual non-duplicates class 97% are predicted accuractely and Out of total actual duplicates class 20% are predicted accuractely.<br>4. f1 score for non-duplicate class is 80% and for duplicate class is 32%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# ### Inference about these 3 algorithm:
# 1. **Naive Bayes is faster and accuracy is also moderate but it required "Dense" array for training. Due to less computational power and RAM size we cannot run this algorithm or such large data set.**
# 2. **SVC gives moderate accuracy but the training and model size is huge.**
# 3. **KNN giving very less accuracy and the model size is also large.**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+ +---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h1 style="background:pink; color:blue; line-height:1.2; font-family:Arial Black; text-align:center;">Running Above two Approached after Balancing the Data, each class containing 25000 rows</h1>
# <h3 style="color:gray;">Lets check how accuracy and other evaluation metrics affected when we use balanced data.</h3>

# %%
class_1_df=data[data['is_duplicate']==1]
class_0_df=data[data['is_duplicate']==0]
print(class_1_df.shape)
print(class_0_df.shape)
# Out:
# (149263, 3)
# (255024, 3)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Selecting 25000 random samples from each class and concetanating to create balanced dataset containing equal number of rows in each class.</h3>

# %%
sample_class_1=class_1_df.sample(25000, random_state=0, ignore_index=True)
sample_class_0=class_0_df.sample(25000, random_state=0, ignore_index=True)
balanced=pd.concat([sample_class_1, sample_class_0], ignore_index=True)
balanced.head()
# Out:
#                                                  question1  \
# 0    What minor would complement a Computer Science major?
# 1                           How can I materialize an idea?
# 2  What was the happiest day of your life? And why was it?
# 3         What role Project manager has in Agile projects?
# 4  Who will win in America presidential elections in 2016?
#
#                                                                question2  \
# 0    What is a good minor that will compliment a Computer Science major?
# 1                        What is the best way to materialize on an idea?
# 2                   What (was/is/will be) the happiest day of your life?
# 3  What is the role of project management in agile software development?
# 4       Between Trump and Clinton who will win US presidential election?
#
#    is_duplicate
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
balanced['is_duplicate'].value_counts()
# Out:
# 1    25000
# 0    25000
# Name: is_duplicate, dtype: int64

# %%
balanced.to_csv("data/data_balanced.csv", index=False)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Divide data into Input and Output</h3>

# %%
X=balanced[['question1','question2']]
y=balanced['is_duplicate']

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Train Test Split</h3>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Convert every sentence to lower case</h3>

# %%
import re
def clean_test_for_sample_data(text):
    text=str(text).lower()
    text=re.sub("[^a-z]", " ", text)
    text=re.sub(" +", " ", text)
    return text

x_train['question1']=x_train['question1'].apply(clean_test_for_sample_data)
x_train['question2']=x_train['question2'].apply(clean_test_for_sample_data)
x_test['question1']=x_test['question1'].apply(clean_test_for_sample_data)
x_test['question2']=x_test['question2'].apply(clean_test_for_sample_data)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Text to numeric conversion</h3>

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Technique Count Vectorizer</h3>

# %%
questions_train=list(x_train['question1'])+list(x_train['question2'])
questions_test=list(x_test['question1'])+list(x_test['question2'])
questions_test[:5]
# Out:
# ['what percent of people in the world believe the earth is flat ',
#  'how do i reset my gmail password when i don t remember my recovery information ',
#  'do demonetization will have any impact on npas ',
#  'how do i find a great web developer ',
#  'why am i getting headache ']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cnv=CountVectorizer(ngram_range=(1, 3))
cnv_fit=cnv.fit(questions_train)
x_train_ques=cnv_fit.transform(questions_train)
q1_array=x_train_ques[:(x_train_ques.shape[0]//2),]  #Vector containing question1
q2_array=x_train_ques[(x_train_ques.shape[0]//2):,]  #Vector containing question2

# %%
from scipy.sparse import hstack
x_train_tf = hstack((q1_array, q2_array))  #Concatenating as a single Vector

# %%
print("X train Transformed Shape", x_train_tf.shape)
print("y train Shape", y_train.shape)
# Out:
# X train Transformed Shape (40000, 1224582)
# y train Shape (40000,)

# %% [markdown]
# ### Now Vectorize x test

# %%
x_test_ques=cnv_fit.transform(questions_test)
q1_array=x_test_ques[:(x_test_ques.shape[0]//2),]
q2_array=x_test_ques[(x_test_ques.shape[0]//2):,]
x_test_tf = hstack((q1_array, q2_array))

# %%
print("X test Transformed Shape", x_test_tf.shape)
print("y test Shape", y_test.shape)
# Out:
# X test Transformed Shape (10000, 1224582)
# y test Shape (10000,)

# %%
len(cnv.vocabulary_)
# Out:
# 612291

# %% [markdown]
# **<code style="color:green">We have 6,12,291 unique vocabulary.</code>**

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Built Machine Learning Classification models and record the experiment using MLFLOW</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Set Experiment</h3>

# %%
import mlflow
mlflow.set_experiment("Simple Approach after Data Balance")
# Out:
# <Experiment: artifact_location='file:///D:/DATA%20SCIENCE%20Internship%20with%20Innomatics/Final_%20Project_Quora_Question_Pair_Similarity/mlruns/887241753423321443', creation_time=1685323992337, experiment_id='887241753423321443', last_update_time=1685323992337, lifecycle_stage='active', name='Simple Approach after Data Balance', tags={}>

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">1. Logistic Regression</h3>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Logistic CntVect")
    
    log_regression=LogisticRegression()
    log_regression.fit(x_train_tf,y_train)
    #pickle.dump(log_regression, open("resources_simple_approach/logistic_regression.pkl","wb"))
    
    y_pred=log_regression.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/log_reg_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(log_regression, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/log_reg_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7207
# Precission=0.7161025239679123
# Recall=0.7317073170731707
# F1 Score=0.7238208246811035
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2793 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72      4998
#            1       0.72      0.73      0.72      5002
#
#     accuracy                           0.72     10000
#    macro avg       0.72      0.72      0.72     10000
# weighted avg       0.72      0.72      0.72     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the logistic regression model is 72%. <br>2. Out of total non-duplicate predicted class 73% are accurate and Out of total duplicate predicted class 72% are accurate.<br>3. Out of total actual non-duplicates class 71% are predicted accuractely and Out of total actual duplicates class 73% are predicted accuractely.<br>4. f1 score for non-duplicate class is 72% and for duplicate class is 72%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">2. Decision Tree Classifier</h3>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Decision Tree CntVect")
    
    dt_classifier=DecisionTreeClassifier()
    dt_classifier.fit(x_train_tf,y_train)
    #pickle.dump(dt_classifier, open("resources_simple_approach/decision_tree.pkl","wb"))
    
    y_pred=dt_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/decision_tree_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(dt_classifier, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/decision_tree_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6649
# Precission=0.6639523336643496
# Recall=0.6683326669332267
# F1 Score=0.6661352993922487
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3351 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66      4998
#            1       0.66      0.67      0.67      5002
#
#     accuracy                           0.66     10000
#    macro avg       0.66      0.66      0.66     10000
# weighted avg       0.66      0.66      0.66     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Decision tree classifier is 67%. <br>2. Out of total non-duplicate predicted class 67% are accurate and Out of total duplicate predicted class 66% are accurate.<br>3. Out of total actual non-duplicates class 66% are predicted accuractely and Out of total actual duplicates class 67% are predicted accuractely.<br>4. f1 score for non-duplicate class is 66% and for duplicate class is 67%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">3. Random Forest Classifier</h3>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Random Forest CntVect")
    
    rf_classifier=RandomForestClassifier()
    rf_classifier.fit(x_train_tf,y_train)
    #pickle.dump(rf_classifier, open("resources_simple_approach/random_forest.pkl","wb"))
    
    y_pred=rf_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/random_forest_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(rf_classifier, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/random_forest_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7262
# Precission=0.7512205947625389
# Recall=0.6767293082766893
# F1 Score=0.712031973075305
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2738 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      4998
#            1       0.75      0.68      0.71      5002
#
#     accuracy                           0.73     10000
#    macro avg       0.73      0.73      0.73     10000
# weighted avg       0.73      0.73      0.73     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Random Forest Classifier is 73%. <br>2. Out of total non-duplicate predicted class 71% are accurate and Out of total duplicate predicted class 75% are accurate.<br>3. Out of total actual non-duplicates class 78% are predicted accuractely and Out of total actual duplicates class 68% are predicted accuractely.<br>4. f1 score for non-duplicate class is 74% and for duplicate class is 71%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">4. XG Boost Classifier</h3>

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "XG Boost CntVect")
    
    xgb_classifier=XGBClassifier()
    xgb_classifier.fit(x_train_tf,y_train)
    #pickle.dump(xgb_classifier, open("resources_advance_approach_with_TFIDF/xgboost.pkl","wb"))
    
    y_pred=xgb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/xgboost_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(xgb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/xgboost_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7208
# Precission=0.7186387020182035
# Recall=0.726109556177529
# F1 Score=0.7223548130469373
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2792 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      4998
#            1       0.72      0.73      0.72      5002
#
#     accuracy                           0.72     10000
#    macro avg       0.72      0.72      0.72     10000
# weighted avg       0.72      0.72      0.72     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the XG Boost Classifier is 72%. <br>2. Out of total non-duplicate predicted class 72% are accurate and Out of total duplicate predicted class 72% are accurate.<br>3. Out of total actual non-duplicates class 72% are predicted accuractely and Out of total actual duplicates class 73% are predicted accuractely.<br>4. f1 score for non-duplicate class is 72% and for duplicate class is 72%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# ### Inference of Basic Approach with Count Vectorizer after Data Balance:
# 1. **Accuracy is high(72%) in both Logistic regression and XGBoost and Random Forest.**
# 2. **Precission is high(75%) in Logistic and XGBoost.**
# 3. **Recall score is high(73%) in Logistic Regression.**
# 4. **F1 score is high(72%) in Logistic Regression and XGBoost**
# 5. **In the basic approach after data balance and using Count vectorizer the "XG Boost" model performance is good.**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Technique-2 TF-IDF Vectorizer</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Text to numerical conversion using TF-IDF</h3>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from scipy.sparse import hstack
x_train_tf = hstack((q1_array, q2_array))  #Concatenating as a single Vector
print("X train Transformed Shape", x_train_tf.shape)
print("y train Shape", y_train.shape)
# Out:
# X train Transformed Shape (40000, 1224582)
# y train Shape (40000,)

# %% [markdown]
# ### Now Vectorize X test

# %%
x_test_ques=tfidf_fit.transform(questions_test)
q1_array=x_test_ques[:(x_test_ques.shape[0]//2),]
q2_array=x_test_ques[(x_test_ques.shape[0]//2):,]
x_test_tf = hstack((q1_array, q2_array))

# %%
print("X test Transformed Shape", x_test_tf.shape)
print("y test Shape", y_test.shape)
# Out:
# X test Transformed Shape (10000, 1224582)
# y test Shape (10000,)

# %%
len(tfidf.vocabulary_)
# Out:
# 612291

# %% [markdown]
# **<code style="color:green">We have 6,12,291 unique vocabulary.</code>**

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Built Machine Learning Classification models and record the experiment using MLFLOW</h3>

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">1. Logistic Regression</h3>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Logistic TfIdf")
    
    log_regression=LogisticRegression()
    log_regression.fit(x_train_tf,y_train)
    #pickle.dump(log_regression, open("resources_simple_approach/logistic_regression.pkl","wb"))
    
    y_pred=log_regression.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/log_reg_tfidf_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(log_regression, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/log_reg_tfidf_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7073
# Precission=0.6907519764662622
# Recall=0.7510995601759296
# F1 Score=0.7196628675414232
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2927 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.73      0.66      0.69      4998
#            1       0.69      0.75      0.72      5002
#
#     accuracy                           0.71     10000
#    macro avg       0.71      0.71      0.71     10000
# weighted avg       0.71      0.71      0.71     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the logistic regression model is 73%. <br>2. Out of total non-duplicate predicted class 73% are accurate and Out of total duplicate predicted class 69% are accurate.<br>3. Out of total actual non-duplicates class 66% are predicted accuractely and Out of total actual duplicates class 75% are predicted accuractely.<br>4. f1 score for non-duplicate class is 69% and for duplicate class is 72%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">2. Decision Tree Classifier</h3>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Decision Tree TfIdf")
    
    dt_classifier=DecisionTreeClassifier()
    dt_classifier.fit(x_train_tf,y_train)
    #pickle.dump(dt_classifier, open("resources_advance_approach_with_TFIDF/decision_tree.pkl","wb"))
    
    y_pred=dt_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/decision_tree_tfidf_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(dt_classifier, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/decision_tree_tfidf_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6009
# Precission=0.5835951711592525
# Recall=0.7055177928828469
# F1 Score=0.6387908408000724
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3991 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.63      0.50      0.55      4998
#            1       0.58      0.71      0.64      5002
#
#     accuracy                           0.60     10000
#    macro avg       0.61      0.60      0.60     10000
# weighted avg       0.61      0.60      0.60     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Decision Tree Classifier is 60%. <br>2. Out of total non-duplicate predicted class 63% are accurate and Out of total duplicate predicted class 58% are accurate.<br>3. Out of total actual non-duplicates class 50% are predicted accuractely and Out of total actual duplicates class 71% are predicted accuractely.<br>4. f1 score for non-duplicate class is 55% and for duplicate class is 64%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">3. Random Forest Classifier</h3>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Random Forest TfIdf")
    
    rf_classifier=RandomForestClassifier()
    rf_classifier.fit(x_train_tf,y_train)
    #pickle.dump(rf_classifier, open("resources_advance_approach_with_TFIDF/random_forest.pkl","wb"))
    
    y_pred=rf_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/random_forest_tfidf_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(rf_classifier, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/random_forest_tfidf_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6743
# Precission=0.6372071080358547
# Recall=0.8100759696121551
# F1 Score=0.7133174896576006
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3257 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.74      0.54      0.62      4998
#            1       0.64      0.81      0.71      5002
#
#     accuracy                           0.67     10000
#    macro avg       0.69      0.67      0.67     10000
# weighted avg       0.69      0.67      0.67     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Random Forest Classifier is 67%. <br>2. Out of total non-duplicate predicted class 74% are accurate and Out of total duplicate predicted class 64% are accurate.<br>3. Out of total actual non-duplicates class 54% are predicted accuractely and Out of total actual duplicates class 81% are predicted accuractely.<br>4. f1 score for non-duplicate class is 62% and for duplicate class is 71%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">4. XG Boost Classifier</h3>

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "XG Boost TfIdf")
    
    xgb_classifier=XGBClassifier()
    xgb_classifier.fit(x_train_tf,y_train)
    #pickle.dump(xgb_classifier, open("resources_simple_approach/xgboost.pkl","wb"))
    
    y_pred=xgb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_basic_approach_after_data_balance/xgboost_tfidf_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(xgb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_basic_approach_after_data_balance/xgboost_tfidf_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.6529
# Precission=0.6132228960212986
# Recall=0.8288684526189524
# F1 Score=0.7049222137209896
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 3471 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.74      0.48      0.58      4998
#            1       0.61      0.83      0.70      5002
#
#     accuracy                           0.65     10000
#    macro avg       0.67      0.65      0.64     10000
# weighted avg       0.67      0.65      0.64     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the XG Boost Classifier is 65%. <br>2. Out of total non-duplicate predicted class 74% are accurate and Out of total duplicate predicted class 61% are accurate.<br>3. Out of total actual non-duplicates class 48% are predicted accuractely and Out of total actual duplicates class 83% are predicted accuractely.<br>4. f1 score for non-duplicate class is 58% and for duplicate class is 70%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# ### Inference of Basic Approach with TFIDF Vectorizer after class Balance:
# 1. **Accuracy is high(71%) in both Logistic regression.**
# 2. **Precission is high(79%) in Logistic Regression.**
# 3. **Recall score is high(62%) in Decision Tree.**
# 4. **F1 score is high(83%) in XGBoost**
# 5. **In the basic approach after class balancing and using TFIDF vectorizer the "Logistic Regression" model performance is good. But Performnce is good when we used CountVectorizer**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+ +---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**

# %% [markdown]
# <h1 style="background:pink; color:black; text-align:center; line-height:2.2; font-family:Arial Black">Advanced Approach to solve this problem using basic and advanced Extracted Features, using BOW Text to Numerical Conversation Technique and using Machine Learning Algorithms and Simple Neural Network</h1>

# %%
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
balanced=pd.read_csv('data/data_balanced.csv')
balanced.head()
# Out:
#                                            question1  \
# 0  What minor would complement a Computer Science...
# 1                     How can I materialize an idea?
# 2  What was the happiest day of your life? And wh...
# 3   What role Project manager has in Agile projects?
# 4  Who will win in America presidential elections...
#
#                                            question2  is_duplicate
# 0  What is a good minor that will compliment a Co...             1
# 1    What is the best way to materialize on an idea?             1
# 2  What (was/is/will be) the happiest day of your...             1
# 3  What is the role of project management in agil...             1
# 4  Between Trump and Clinton who will win US pres...             1

# %%
balanced.shape
# Out:
# (50000, 3)

# %%
class_balance=pd.DataFrame(balanced['is_duplicate'].value_counts()).reset_index()
class_balance.columns=["Class", "Count"]
class_balance['Percentage']=(class_balance['Count']/balanced.shape[0])*100
class_balance
# Out:
#    Class  Count  Percentage
# 0      1  25000        50.0
# 1      0  25000        50.0

# %%
label=['Non-Duplicate', 'Duplicate'] 
color=sns.color_palette('rainbow')[4:6]
plt.figure(figsize=(6,6))
plt.pie(x=class_balance['Count'], labels=label, colors=color, autopct='%.0f%%' , labeldistance=0.5)
plt.title("Count of Non-Duplicate and Duplicate questions", fontsize=18, color='green');

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Text Preprocessing</h3>

# %%
import contractions
import re

# %%
def clean_test_for_sample_data(text):
    text=str(text).lower()
    text=text.replace('%', ' percent')
    text=text.replace('$', ' dollar ')
    text=text.replace('₹', ' rupee ')
    text=text.replace('€', ' euro ')
    text=text.replace('@', ' at ')
        
    text=text.replace(',000,000,000 ', 'b ')
    text=text.replace(',000,000 ', 'm ')
    text=text.replace(',000 ', 'k ')
    text=re.sub(r'([0-9]+)000000000', r'\1b', text)
    text=re.sub(r'([0-9]+)000000', r'\1m', text)
    text=re.sub(r'([0-9]+)000', r'\1k', text)
    pattern=re.compile('\W')
    text=re.sub(pattern, ' ', text).strip()
    #text=" ".join(text)
    text=re.sub("<.*?>", "", text)
    text=contractions.fix(text)
    text=re.sub(" +", " ", text)
    #text=text.strip()
    return text

balanced['question1']=balanced['question1'].apply(clean_test_for_sample_data)
balanced['question2']=balanced['question2'].apply(clean_test_for_sample_data)
pd.options.display.max_colwidth=10000000000000
balanced.head()
# Out:
#                                                 question1  \
# 0    what minor would complement a computer science major
# 1                           how can i materialize an idea
# 2   what was the happiest day of your life and why was it
# 3         what role project manager has in agile projects
# 4  who will win in america presidential elections in 2016
#
#                                                               question2  \
# 0    what is a good minor that will compliment a computer science major
# 1                        what is the best way to materialize on an idea
# 2                     what was is will be the happiest day of your life
# 3  what is the role of project management in agile software development
# 4       between trump and clinton who will win us presidential election
#
#    is_duplicate
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">Extract Basic Features</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.2; font-family:Arial Black; text-align:left">1. Question Length</h3>

# %%
balanced['que1_len']=balanced['question1'].str.len()
balanced['que2_len']=balanced['question2'].str.len()

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1; font-family:Arial Black; text-align:left">Anayze Question Length column</h3>

# %%
print("Statistics on Question-1 Length")
print(balanced['que1_len'].describe().T)
print("--"*30)
print("Statistics on Question-2 Length")
print(balanced['que2_len'].describe().T)
print("--"*30)
print("Statistics on Question-1 Length when Non-Duplicate")
print(balanced[balanced['is_duplicate']==0]['que1_len'].describe().T)
print("--"*30)
print("Statistics on Question-1 Length when Duplicate")
print(balanced[balanced['is_duplicate']==1]['que1_len'].describe().T)
print("--"*30)
print("Statistics on Question-2 Length when Non-Duplicate")
print(balanced[balanced['is_duplicate']==0]['que2_len'].describe().T)
print("--"*30)
print("Statistics on Question-2 Length when Duplicate")
print(balanced[balanced['is_duplicate']==1]['que2_len'].describe().T)
print("--"*30)
# Out:
# Statistics on Question-1 Length
# count    50000.000000
# mean        56.855320
# std         28.650849
# min          0.000000
# 25%         38.000000
# 50%         50.000000
# 75%         68.000000
# max        435.000000
# Name: que1_len, dtype: float64
# ------------------------------------------------------------
# Statistics on Question-2 Length
# count    50000.000000
# mean        57.186300
# std         31.070809
# min          2.000000
# 25%         37.000000
# 50%         49.000000
# 75%         68.000000
# max        616.000000
# Name: que2_len, dtype: float64
# ------------------------------------------------------------
# Statistics on Question-1 Length when Non-Duplicate
# count    25000.000000
# mean        62.219440
# std         32.462902
# min          0.000000
# 25%         40.000000
# 50%         54.000000
# 75%         76.000000
# max        391.000000
# Name: que1_len, dtype: float64
# ------------------------------------------------------------
# ...

# %%
plt.figure(figsize=(18,5))
plt.subplot(121)
sns.distplot(balanced[balanced['is_duplicate'] == 0]['que1_len'], label='Non-Duplicate', color='red')
sns.distplot(balanced[balanced['is_duplicate'] == 1]['que1_len'], label='Duplicate', color='green')
plt.legend();

plt.subplot(122)
sns.distplot(balanced[balanced['is_duplicate'] == 0]['que2_len'], label='Non-Duplicate', color='red')
sns.distplot(balanced[balanced['is_duplicate'] == 1]['que2_len'], label='Duplicate', color='green')
plt.legend();

plt.suptitle("Question length for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">Mean and standard deviation of duplicate question pair is lower than the Non-Duplicate question pairs. From Grapgh the peak for Duplicate question is slightly higher than Non-Duplicate. But Cannot distinguish Duplicate and Non-Duplicate question pair exactly on the basis of question lengths.</code>**

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.2; font-family:Arial Black; text-align:left">2. Number of Words in Question</h3>

# %%
balanced['que1_num_words'] =balanced['question1'].apply(lambda sent: len(sent.split()))
balanced['que2_num_words'] =balanced['question2'].apply(lambda sent: len(sent.split()))

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1; font-family:Arial Black; text-align:left">Anayze Count of Question Words column</h3>

# %%
print("Statistics on Question-1 Word Count")
print(balanced['que1_num_words'].describe().T)
print("--"*30)
print("Statistics on Question-2 Word Count")
print(balanced['que2_len'].describe().T)
print("--"*30)
print("Statistics on Question-1 Word Count when Non-Duplicate")
print(balanced[balanced['is_duplicate']==0]['que1_num_words'].describe().T)
print("--"*30)
print("Statistics on Question-1 Word Count when Duplicate")
print(balanced[balanced['is_duplicate']==1]['que1_num_words'].describe().T)
print("--"*30)
print("Statistics on Question-2 Word Count when Non-Duplicate")
print(balanced[balanced['is_duplicate']==0]['que2_num_words'].describe().T)
print("--"*30)
print("Statistics on Question-2 Word Count when Duplicate")
print(balanced[balanced['is_duplicate']==1]['que2_num_words'].describe().T)
print("--"*30)
# Out:
# Statistics on Question-1 Word Count
# count    50000.000000
# mean        10.904280
# std          5.402538
# min          0.000000
# 25%          7.000000
# 50%         10.000000
# 75%         13.000000
# max         83.000000
# Name: que1_num_words, dtype: float64
# ------------------------------------------------------------
# Statistics on Question-2 Word Count
# count    50000.000000
# mean        57.186300
# std         31.070809
# min          2.000000
# 25%         37.000000
# 50%         49.000000
# 75%         68.000000
# max        616.000000
# Name: que2_len, dtype: float64
# ------------------------------------------------------------
# Statistics on Question-1 Word Count when Non-Duplicate
# count    25000.000000
# mean        11.856160
# std          6.182106
# min          0.000000
# 25%          8.000000
# 50%         10.000000
# 75%         14.000000
# max         74.000000
# Name: que1_num_words, dtype: float64
# ...

# %%
plt.figure(figsize=(18,5))
plt.subplot(121)
sns.distplot(balanced[balanced['is_duplicate'] == 0]['que1_num_words'], label='Non-Duplicate', color='red')
sns.distplot(balanced[balanced['is_duplicate'] == 1]['que1_num_words'], label='Duplicate', color='green')
plt.legend();

plt.subplot(122)
sns.distplot(balanced[balanced['is_duplicate'] == 0]['que2_num_words'], label='Non-Duplicate', color='red')
sns.distplot(balanced[balanced['is_duplicate'] == 1]['que2_num_words'], label='Duplicate', color='green')
plt.legend();

plt.suptitle("Word Counts for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">Mean and Standard Deviation for duplicate question pair is lower than Non-Duplicate question pair. From Grapgh the peak for Duplicate question is slightly higher than Non-Duplicate. Although from graph we cannot exactly distiguish the Duplicate and Non Duplicate question pairs.</code>**

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.2; font-family:Arial Black; text-align:left">3. Total Words in both Questions</h3>

# %%
def total_words(row):
    q1_w=set(map(lambda x: x.lower().strip(), row['question1'].split()))
    q2_w=set(map(lambda x: x.lower().strip(), row['question2'].split()))
    return len(q1_w) + len(q2_w)

balanced['total_words']=balanced.apply(total_words, axis=1)

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1; font-family:Arial Black; text-align:left">Anayze Total Words column</h3>

# %%
print("Statistics on Total Words when Duplicate")
print(balanced[balanced['is_duplicate']==1]['total_words'].describe().T)
print("--"*30)
print("Statistics on Total Word Count when Non-Duplicate")
print(balanced[balanced['is_duplicate']==0]['total_words'].describe().T)
print("--"*30)
# Out:
# Statistics on Total Words when Duplicate
# count    25000.000000
# mean        19.162480
# std          6.645041
# min          6.000000
# 25%         15.000000
# 50%         18.000000
# 75%         22.000000
# max        108.000000
# Name: total_words, dtype: float64
# ------------------------------------------------------------
# Statistics on Total Word Count when Non-Duplicate
# count    25000.000000
# mean        22.578000
# std          9.340358
# min          5.000000
# 25%         16.000000
# 50%         21.000000
# 75%         27.000000
# max        115.000000
# Name: total_words, dtype: float64
# ------------------------------------------------------------

# %%
plt.figure(figsize=(18,5))
sns.distplot(balanced[balanced['is_duplicate'] == 0]['total_words'], label='Non-Duplicate', color='red')
sns.distplot(balanced[balanced['is_duplicate'] == 1]['total_words'], label='Duplicate', color='green')
plt.legend();
plt.suptitle("Total Word Counts for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">Mean and Standard Deviation for duplicate question pair is higher than Non-Duplicate question pair. From Grapgh the peak for Duplicate question is slightly higher than Non-Duplicate. Although from graph we cannot exactly distiguish the Duplicate and Non Duplicate question pairs.</code>**

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.2; font-family:Arial Black; text-align:left">4. Common Words in Questions</h3>

# %%
def common_words(row):
    q1_w=set(map(lambda x: x.lower().strip(), row['question1'].split()))
    q2_w=set(map(lambda x: x.lower().strip(), row['question2'].split()))
    return len(q1_w)&len(q2_w)

balanced['common_words']=balanced.apply(common_words, axis=1)

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1; font-family:Arial Black; text-align:left">Anayze Count of Common Words column</h3>

# %%
print("Statistics on Common Words when Duplicate")
print(balanced[balanced['is_duplicate']==1]['common_words'].describe().T)
print("--"*30)
print("Statistics on Common Word Count when Non-Duplicate")
print(balanced[balanced['is_duplicate']==0]['common_words'].describe().T)
print("--"*30)
# Out:
# Statistics on Common Words when Duplicate
# count    25000.000000
# mean         6.265680
# std          4.330303
# min          0.000000
# 25%          2.000000
# 50%          8.000000
# 75%          8.000000
# max         32.000000
# Name: common_words, dtype: float64
# ------------------------------------------------------------
# Statistics on Common Word Count when Non-Duplicate
# count    25000.000000
# mean         6.491960
# std          5.083897
# min          0.000000
# 25%          2.000000
# 50%          8.000000
# 75%          9.000000
# max         41.000000
# Name: common_words, dtype: float64
# ------------------------------------------------------------

# %%
plt.figure(figsize=(18,5))
sns.distplot(balanced[balanced['is_duplicate'] == 0]['common_words'], label='Non-Duplicate', color='red')
sns.distplot(balanced[balanced['is_duplicate'] == 1]['common_words'], label='Duplicate', color='green')
plt.legend();
plt.suptitle("Total Common Word Counts for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">There is no much difference between Mean and Standard Deviation for duplicate question pair and Non-Duplicate question pair. From Grapgh the peak for Duplicate question and Non-Duplicate question is neck to neck. From graph we cannot exactly distiguish the Duplicate and Non Duplicate question pairs.</code>**

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.2; font-family:Arial Black; text-align:left">5. Word Sharing</h3>

# %%
balanced['shared_words'] = round(balanced['common_words']/balanced['total_words'], 2)

# %% [markdown]
# <h3 style="background:yellow; color:blue; line-height:1; font-family:Arial Black; text-align:left">Anayze Word Sharing column</h3>

# %%
print("Statistics on Word Sharing when Duplicate")
print(balanced[balanced['is_duplicate']==1]['shared_words'].describe().T)
print("--"*30)
print("Statistics on Word Sharing when Non-Duplicate")
print(balanced[balanced['is_duplicate']==0]['shared_words'].describe().T)
print("--"*30)
# Out:
# Statistics on Word Sharing when Duplicate
# count    25000.000000
# mean         0.326673
# std          0.189764
# min          0.000000
# 25%          0.120000
# 50%          0.420000
# 75%          0.480000
# max          0.500000
# Name: shared_words, dtype: float64
# ------------------------------------------------------------
# Statistics on Word Sharing when Non-Duplicate
# count    25000.000000
# mean         0.293140
# std          0.191106
# min          0.000000
# 25%          0.070000
# 50%          0.380000
# 75%          0.460000
# max          0.500000
# Name: shared_words, dtype: float64
# ------------------------------------------------------------

# %%
plt.figure(figsize=(18,5))
sns.distplot(balanced[balanced['is_duplicate'] == 0]['shared_words'], label='Non-Duplicate', color='red')
sns.distplot(balanced[balanced['is_duplicate'] == 1]['shared_words'], label='Duplicate', color='green')
plt.legend();
plt.suptitle(" Word Sharing for Duplicate and Non-Duplicate Question", color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">Cannot Distiguish Duplicate and Non-Duplicate Question Pairs on the basic of Word sharing.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">Extract Token Based Features</h3>

# %% [markdown]
# 1. **cwc_min:** Ratio of the number of common words to the length of the smaller question
# 2. **cwc_max:** Ratio of the number of common words to the length of the larger question
# 3. **csc_min:** Ratio of the number of common stop words to the smaller stop word count among the two questions
# 4. **csc_max:** Ratio of the number of common stop words to the larger stop word count among the two questions
# 5. **ctc_min:** Ratio of the number of common tokens to the smaller token count among the two questions
# 6. **ctc_max:** Ratio of the number of common tokens to the larger token count among the two questions
# 7. **last_word_eq:** 1 if the last word in the two questions is same, 0 otherwise
# 8. **first_word_eq:** 1 if the first word in the two questions is same, 0 otherwise

# %%
from nltk.corpus import stopwords

# %%
def extract_token_features(row):
    q1=row['question1']
    q2=row['question2']
    SAFE_DIV=0.0001
    STOP_WORDS=stopwords.words("english")   #Stopwords
    token_features=[0.0]*8
    
    q1_tokens=q1.split()    #tokens in question1
    q2_tokens=q2.split()    #tokens in question2
    if len(q1_tokens)==0 or len(q2_tokens)==0:
        return token_features

    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])     #non-stopwords in question1
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])     #non-stopwords in question2
    
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])         #stopwords in question1
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])         #stopwords in question2
    
    common_word_count = len(q1_words.intersection(q2_words))                   #non-stopword count
    common_stop_count = len(q1_stops.intersection(q2_stops))                   #common stopword count
    common_token_count=len(set(q1_tokens).intersection(set(q2_tokens)))        #common token count
    
    token_features[0]=common_word_count/(min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1]=common_word_count/(max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2]=common_stop_count/(min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3]=common_stop_count/(max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4]=common_token_count/(min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5]=common_token_count/(max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[6]=int(q1_tokens[-1]==q2_tokens[-1])   #last word same or not
    token_features[7]=int(q1_tokens[0]==q2_tokens[0])     #first word same or not
    
    return token_features

# %%
token_features=balanced.apply(extract_token_features, axis=1)

balanced["cwc_min"]=list(map(lambda x: x[0], token_features))
balanced["cwc_max"]=list(map(lambda x: x[1], token_features))
balanced["csc_min"]=list(map(lambda x: x[2], token_features))
balanced["csc_max"]=list(map(lambda x: x[3], token_features))
balanced["ctc_min"]= list(map(lambda x: x[4], token_features))
balanced["ctc_max"]=list(map(lambda x: x[5], token_features))
balanced["last_word_eq"]=list(map(lambda x: x[6], token_features))
balanced["first_word_eq"]=list(map(lambda x: x[7], token_features))

balanced.head(2)
# Out:
#                                               question1  \
# 0  what minor would complement a computer science major
# 1                         how can i materialize an idea
#
#                                                             question2  \
# 0  what is a good minor that will compliment a computer science major
# 1                      what is the best way to materialize on an idea
#
#    is_duplicate  que1_len  que2_len  que1_num_words  que2_num_words  \
# 0             1        52        66               8              12
# 1             1        29        46               6              10
#
#    total_words  common_words  shared_words   cwc_min   cwc_max   csc_min  \
# 0           19             8          0.42  0.666656  0.666656  0.999950
# 1           16             2          0.12  0.999950  0.499988  0.249994
#
#     csc_max   ctc_min   ctc_max  last_word_eq  first_word_eq
# 0  0.399992  0.749991  0.499996           1.0            1.0
# ...

# %%
token_features_df=token_features_df.drop('is_duplicate', axis=1)
for col in token_features_df.columns:
    plt.figure(figsize=(18,5))
    sns.distplot(balanced[balanced['is_duplicate'] == 0][col], label='Non-Duplicate', color='red')
    sns.distplot(balanced[balanced['is_duplicate'] == 1][col], label='Duplicate', color='green')
    plt.legend();
    plt.suptitle("Relationship between {} and is duplicate".format(col), color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">It is possible to seperate class 0 and class 1 on the basic of token features.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">Extract Length Based Features</h3>

# %% [markdown]
# 1. **mean_len:** Average of both questions length.
# 2. **abs_len_diff:** Absolute difference between the length of the two questions.
# 3. **long_substr_ratio:** The ratio of the length of the longest substring between two questions is divided by the length of the smaller questions.

# %%
import distance
def extract_length_features(row):
    q1=row['question1']
    q2=row['question2']
    length_features=[0.0]*3
    
    q1_tokens=q1.split()   #question1 token
    q2_tokens=q2.split()   #question2 token
    if len(q1_tokens)==0 or len(q2_tokens)==0:
        return length_features
    
    length_features[0]=abs(len(q1_tokens) - len(q2_tokens))            #absolute length difference
    length_features[1]=(len(q1_tokens) + len(q2_tokens))/2             #average token length
    strs=list(distance.lcsubstrings(q1, q2))                           #longest substring
    length_features[2]=len(strs[0]) / (min(len(q1), len(q2)) + 1)      #longest substring ratio
    
    return length_features

# %%
length_features=balanced.apply(extract_length_features, axis=1)

balanced['abs_len_diff'] = list(map(lambda x: x[0], length_features))
balanced['mean_len'] = list(map(lambda x: x[1], length_features))
balanced['long_substr_ratio'] = list(map(lambda x: x[2], length_features))
balanced.head(2)
# Out:
#                                               question1  \
# 0  what minor would complement a computer science major
# 1                         how can i materialize an idea
#
#                                                             question2  \
# 0  what is a good minor that will compliment a computer science major
# 1                      what is the best way to materialize on an idea
#
#    is_duplicate  que1_len  que2_len  que1_num_words  que2_num_words  \
# 0             1        52        66               8              12
# 1             1        29        46               6              10
#
#    total_words  common_words  shared_words  ...   cwc_max   csc_min   csc_max  \
# 0           19             8          0.42  ...  0.666656  0.999950  0.399992
# 1           16             2          0.12  ...  0.499988  0.249994  0.166664
#
#     ctc_min   ctc_max  last_word_eq  first_word_eq  abs_len_diff  mean_len  \
# ...

# %%
length_features_df=length_features_df.drop('is_duplicate', axis=1)
for col in length_features_df.columns:
    plt.figure(figsize=(18,5))
    sns.distplot(balanced[balanced['is_duplicate'] == 0][col], label='Non-Duplicate', color='red')
    sns.distplot(balanced[balanced['is_duplicate'] == 1][col], label='Duplicate', color='green')
    plt.legend();
    plt.suptitle("Relationship between {} and is duplicate".format(col), color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">Clearly from graphs we can say that it is possible to seperate class 0 and class 1 from these length based features.</code>**

# %% [markdown]
# <h3 style="background:pink; color:blue; line-height:1.7; font-family:Arial Black; text-align:left">Extract Fuzzy Features</h3>

# %% [markdown]
# 1. **fuzz_ratio:** fuzz_ratio score from fuzzywuzzy, higher the score higher the similarity.
# 2. **fuzz_partial_ratio:** fuzz_partial_ratio from fuzzywuzzy, if one sentence words present in other, score will be high. In other word one string shoulb subset of other so the score will be high.
# 3. **token_sort_ratio:** token_sort_ratio from fuzzywuzzy, If the same sentence occure with different ordering. then score will be high.
# 4. **token_set_ratio:** token_set_ratio from fuzzywuzzy, It consider set of unique word to compare to other string.

# %%
from fuzzywuzzy import fuzz
def extract_fuzzy_features(row):
    q1 = row['question1']
    q2 = row['question2']
    fuzzy_features = [0.0]*4
    
    fuzzy_features[0] = fuzz.QRatio(q1, q2)              #fuzzy ration
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)       #fuzzy partial_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)    #token sort ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)     #token set ratio

    return fuzzy_features

# %%
fuzzy_features=balanced.apply(extract_fuzzy_features, axis=1)

balanced['fuzz_ratio'] = list(map(lambda x: x[0], fuzzy_features))
balanced['fuzz_partial_ratio'] = list(map(lambda x: x[1], fuzzy_features))
balanced['token_sort_ratio'] = list(map(lambda x: x[2], fuzzy_features))
balanced['token_set_ratio'] = list(map(lambda x: x[3], fuzzy_features))
balanced.head(2)
# Out:
#                                               question1  \
# 0  what minor would complement a computer science major
# 1                         how can i materialize an idea
#
#                                                             question2  \
# 0  what is a good minor that will compliment a computer science major
# 1                      what is the best way to materialize on an idea
#
#    is_duplicate  que1_len  que2_len  que1_num_words  que2_num_words  \
# 0             1        52        66               8              12
# 1             1        29        46               6              10
#
#    total_words  common_words  shared_words  ...   ctc_max  last_word_eq  \
# 0           19             8          0.42  ...  0.499996           1.0
# 1           16             2          0.12  ...  0.299997           1.0
#
#    first_word_eq  abs_len_diff  mean_len  long_substr_ratio  fuzz_ratio  \
# 0            1.0           4.0      10.0           0.547170          81
# ...

# %%
fuzzy_features_df=fuzzy_features_df.drop('is_duplicate', axis=1)
for col in fuzzy_features_df.columns:
    plt.figure(figsize=(18,5))
    sns.distplot(balanced[balanced['is_duplicate'] == 0][col], label='Non-Duplicate', color='red')
    sns.distplot(balanced[balanced['is_duplicate'] == 1][col], label='Duplicate', color='green')
    plt.legend();
    plt.suptitle("Relationship between {} and is duplicate".format(col), color='blue', fontsize=18);

# %% [markdown]
# **<code style="color:red;">Clearly from graph we can seperate two classes.</code>**

# %% [markdown]
# ### Save this Dataset with extracted features.

# %%
#balanced.to_csv("data/feat_extr_data.csv", index=False)
balanced=pd.read_csv("data/feat_extr_data.csv")
balanced.head(2)
# Out:
#                                            question1  \
# 0  what minor would complement a computer science...
# 1                      how can i materialize an idea
#
#                                            question2  is_duplicate  que1_len  \
# 0  what is a good minor that will compliment a co...             1        52
# 1     what is the best way to materialize on an idea             1        29
#
#    que2_len  que1_num_words  que2_num_words  total_words  common_words  \
# 0        66               8              12           19             8
# 1        46               6              10           16             2
#
#    shared_words  ...   ctc_max  last_word_eq  first_word_eq  abs_len_diff  \
# 0          0.42  ...  0.499996           1.0            1.0           4.0
# 1          0.12  ...  0.299997           1.0            0.0           4.0
#
#    mean_len  long_substr_ratio  fuzz_ratio  fuzz_partial_ratio  \
# ...

# %%
balanced.shape
# Out:
# (49998, 25)

# %%
balanced.isna().sum()
# Out:
# question1             0
# question2             0
# is_duplicate          0
# que1_len              0
# que2_len              0
# que1_num_words        0
# que2_num_words        0
# total_words           0
# common_words          0
# shared_words          0
# cwc_min               0
# cwc_max               0
# csc_min               0
# csc_max               0
# ctc_min               0
# ctc_max               0
# last_word_eq          0
# first_word_eq         0
# abs_len_diff          0
# mean_len              0
# long_substr_ratio     0
# fuzz_ratio            0
# fuzz_partial_ratio    0
# token_sort_ratio      0
# token_set_ratio       0
# dtype: int64

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Divide data into Input and Output</h3>

# %%
X=balanced.drop("is_duplicate", axis=1)
y=balanced['is_duplicate']

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Train Test Split</h3>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Text to numeric conversion</h3>
# <h3 style="background:yellow; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Technique: Count Vectorizer</h3>

# %%
questions_train=list(x_train['question1'])+list(x_train['question2'])
questions_test=list(x_test['question1'])+list(x_test['question2'])
questions_test[:5]
# Out:
# ['what percent of people in the world believe the earth is flat',
#  'what are the best good websites to learn coding',
#  'what can cause third world war',
#  'what are the limitations of scala programming language',
#  'where can i find reviews for the philips norelco g370 charger']

# %%
extracted_features=['que1_len', 'que2_len',
       'que1_num_words', 'que2_num_words', 'total_words', 'common_words',
       'shared_words', 'cwc_min', 'cwc_max', 'csc_min', 'csc_max', 'ctc_min',
       'ctc_max', 'last_word_eq', 'first_word_eq', 'abs_len_diff', 'mean_len',
       'long_substr_ratio', 'fuzz_ratio', 'fuzz_partial_ratio',
       'token_sort_ratio', 'token_set_ratio']

# %%
extracted_features_train=x_train[extracted_features]
extracted_features_test=x_test[extracted_features]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cnv=CountVectorizer(ngram_range=(1, 2))
cnv_fit=cnv.fit(questions_train)
x_train_ques=cnv_fit.transform(questions_train)
q1_array=x_train_ques[:(x_train_ques.shape[0]//2),]  #Vector containing question1
q2_array=x_train_ques[(x_train_ques.shape[0]//2):,]  #Vector containing question2

# %%
from scipy.sparse import hstack
x_train_tf = hstack((q1_array, q2_array, extracted_features_train))  #Concatenating as a single Vector
print("X train Transformed Shape", x_train_tf.shape)
print("y train Shape", y_train.shape)
# Out:
# X train Transformed Shape (39998, 501898)
# y train Shape (39998,)

# %% [markdown]
# ### Now Vectorize x test

# %%
x_test_ques=cnv_fit.transform(questions_test)
q1_array=x_test_ques[:(x_test_ques.shape[0]//2),]
q2_array=x_test_ques[(x_test_ques.shape[0]//2):,]
x_test_tf = hstack((q1_array, q2_array, extracted_features_test))
print("X test Transformed Shape", x_test_tf.shape)
print("y test Shape", y_test.shape)
# Out:
# X test Transformed Shape (10000, 501898)
# y test Shape (10000,)

# %%
len(cnv.vocabulary_)
# Out:
# 250938

# %% [markdown]
# **<code style="color:green">We have 2,50,938 unique vocabulary.</code>**

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.5; font-family:Arial Black; text-align:left">Built Machine Learning Classification models and record the experiment using MLFLOW</h3>

# %% [markdown]
# <h3 style="background:lightblue; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">Set Experiment</h3>

# %%
import mlflow
mlflow.set_experiment("Advance Approach using extracted features")
# Out:
# <Experiment: artifact_location='file:///D:/DATA%20SCIENCE%20Internship%20with%20Innomatics/Final_%20Project_Quora_Question_Pair_Similarity/mlruns/756603619414327377', creation_time=1685423950617, experiment_id='756603619414327377', last_update_time=1685423950617, lifecycle_stage='active', name='Advance Approach using extracted features', tags={}>

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">1. Logistic Regression</h3>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Logistic adv")
    
    log_regression=LogisticRegression()
    log_regression.fit(x_train_tf,y_train)
    #pickle.dump(log_regression, open("resources_simple_approach/logistic_regression.pkl","wb"))
    
    y_pred=log_regression.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_using_extracted_features/log_reg_adv_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(log_regression, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_using_extracted_features/log_reg_adv_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7316
# Precission=0.7183620529924032
# Recall=0.7690934338424915
# F1 Score=0.7428626173596474
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2684 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.75      0.69      0.72      4959
#            1       0.72      0.77      0.74      5041
#
#     accuracy                           0.73     10000
#    macro avg       0.73      0.73      0.73     10000
# weighted avg       0.73      0.73      0.73     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Logistic Regression is 73%. <br>2. Out of total non-duplicate predicted class 75% are accurate and Out of total duplicate predicted class 72% are accurate.<br>3. Out of total actual non-duplicates class 69% are predicted accuractely and Out of total actual duplicates class 77% are predicted accuractely.<br>4. f1 score for non-duplicate class is 72% and for duplicate class is 74%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">2. Decision Tree Classifier</h3>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Decision Tree adv")
    
    dt_classifier=DecisionTreeClassifier()
    dt_classifier.fit(x_train_tf,y_train)
    #pickle.dump(dt_classifier, open("resources_advance_approach_with_TFIDF/decision_tree.pkl","wb"))
    
    y_pred=dt_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_using_extracted_features/decision_tree_adv_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(dt_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_using_extracted_features/decision_tree_adv_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7352
# Precission=0.7272554605887939
# Recall=0.7595715135885737
# F1 Score=0.7430622938094315
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2648 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.74      0.71      0.73      4959
#            1       0.73      0.76      0.74      5041
#
#     accuracy                           0.74     10000
#    macro avg       0.74      0.73      0.73     10000
# weighted avg       0.74      0.74      0.74     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Decision Tree Classifier is 74%. <br>2. Out of total non-duplicate predicted class 74% are accurate and Out of total duplicate predicted class 73% are accurate.<br>3. Out of total actual non-duplicates class 71% are predicted accuractely and Out of total actual duplicates class 76% are predicted accuractely.<br>4. f1 score for non-duplicate class is 73% and for duplicate class is 74%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">3. Random Forest Classifier</h3>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "Random Forest adv")
    
    rf_classifier=RandomForestClassifier()
    rf_classifier.fit(x_train_tf,y_train)
    #pickle.dump(rf_classifier, open("resources_advance_approach_with_TFIDF/random_forest.pkl","wb"))
    
    y_pred=rf_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_using_extracted_features/random_forest_adv_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(rf_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_using_extracted_features/random_forest_adv_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.7888
# Precission=0.7398853398853399
# Recall=0.8960523705613965
# F1 Score=0.810514982953526
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2112 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.87      0.68      0.76      4959
#            1       0.74      0.90      0.81      5041
#
#     accuracy                           0.79     10000
#    macro avg       0.80      0.79      0.79     10000
# weighted avg       0.80      0.79      0.79     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Random Forest Classifier is 79%. <br>2. Out of total non-duplicate predicted class 87% are accurate and Out of total duplicate predicted class 74% are accurate.<br>3. Out of total actual non-duplicates class 68% are predicted accuractely and Out of total actual duplicates class 90% are predicted accuractely.<br>4. f1 score for non-duplicate class is 76% and for duplicate class is 81%.<br>5. f1 score for both the classes should be high.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">4. XG Boost Classifier</h3>

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, f1_score, precision_score, confusion_matrix
import pickle
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "XG Boost adv")
    
    xgb_classifier=XGBClassifier()
    xgb_classifier.fit(x_train_tf,y_train)
    #pickle.dump(xgb_classifier, open("resources_simple_approach/xgboost.pkl","wb"))
    
    y_pred=xgb_classifier.predict(x_test_tf)
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_using_extracted_features/xgboost_adv_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    mlflow.sklearn.log_model(xgb_classifier, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_using_extracted_features/xgboost_adv_conf_matrix.png")
# Out:
# ----------------------------------------------------------
# Acuuracy=0.794
# Precission=0.7509681764606836
# Recall=0.884745090259869
# F1 Score=0.8123861566484517
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# Out of 10000 testing values 2060 are mis-classified.
# ----------------------------------------------------------
# Classification Report=
#                precision    recall  f1-score   support
#
#            0       0.86      0.70      0.77      4959
#            1       0.75      0.88      0.81      5041
#
#     accuracy                           0.79     10000
#    macro avg       0.80      0.79      0.79     10000
# weighted avg       0.80      0.79      0.79     10000
#
# ----------------------------------------------------------

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the XG Boost Classifier is 79%. <br>2. Out of total non-duplicate predicted class 86% are accurate and Out of total duplicate predicted class 75% are accurate.<br>3. Out of total actual non-duplicates class 70% are predicted accuractely and Out of total actual duplicates class 88% are predicted accuractely.<br>4. f1 score for non-duplicate class is 77% and for duplicate class is 81%.<br>5. f1 score for both the classes should be high.<br>6. False Negative count is very less hence XGBoost is suitable model.</code>**

# %% [markdown]
# <h3 style="background:lightgreen; color:blue; line-height:1.3; font-family:Arial Black; text-align:left">5. Simple Neural Network</h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
balanced=pd.read_csv('data/feat_extr_data.csv')
balanced.head(2)
# Out:
#                                               question1  \
# 0  what minor would complement a computer science major
# 1                         how can i materialize an idea
#
#                                                             question2  \
# 0  what is a good minor that will compliment a computer science major
# 1                      what is the best way to materialize on an idea
#
#    is_duplicate  que1_len  que2_len  que1_num_words  que2_num_words  \
# 0             1        52        66               8              12
# 1             1        29        46               6              10
#
#    total_words  common_words  shared_words  ...   ctc_max  last_word_eq  \
# 0           19             8          0.42  ...  0.499996           1.0
# 1           16             2          0.12  ...  0.299997           1.0
#
#    first_word_eq  abs_len_diff  mean_len  long_substr_ratio  fuzz_ratio  \
# 0            1.0           4.0      10.0           0.547170          81
# ...

# %% [markdown]
# ### Taking 20000 Samples due to less computational power.

# %%
balanced=balanced.sample(20000, random_state=0, ignore_index=True)

# %%
balanced['is_duplicate'].value_counts()
# Out:
# 1    10001
# 0     9999
# Name: is_duplicate, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %% [markdown]
# ### Neaural Network only takes dense matrix

# %%
X=balanced.drop("is_duplicate", axis=1)
y=balanced['is_duplicate']

x_train,x_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=0)
questions_train=list(x_train['question1'])+list(x_train['question2'])
questions_test=list(x_test['question1'])+list(x_test['question2'])

extracted_features=['que1_len', 'que2_len', 'que1_num_words', 'que2_num_words', 'total_words', 'common_words',
       'shared_words', 'cwc_min', 'cwc_max', 'csc_min', 'csc_max', 'ctc_min', 'ctc_max', 'last_word_eq', 
       'first_word_eq', 'abs_len_diff', 'mean_len', 'long_substr_ratio', 'fuzz_ratio', 'fuzz_partial_ratio',
       'token_sort_ratio', 'token_set_ratio']
extracted_features_train=x_train[extracted_features]
extracted_features_test=x_test[extracted_features]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import hstack
cnv=CountVectorizer(max_features=5000)
cnv_fit=cnv.fit(questions_train)
x_train_ques=cnv_fit.transform(questions_train)
q1_array=x_train_ques[:(x_train_ques.shape[0]//2),]  #Vector containing question1
q2_array=x_train_ques[(x_train_ques.shape[0]//2):,]  #Vector containing question2
x_train_tf = hstack((q1_array, q2_array, extracted_features_train)).toarray()  #Concatenating as a single Vector
print("X train Transformed Shape", x_train_tf.shape)
print("y train Shape", y_train.shape)

x_test_ques=cnv_fit.transform(questions_test)
q1_array=x_test_ques[:(x_test_ques.shape[0]//2),]
q2_array=x_test_ques[(x_test_ques.shape[0]//2):,]
x_test_tf = hstack((q1_array, q2_array, extracted_features_test)).toarray()
print("X test Transformed Shape", x_test_tf.shape)
print("y test Shape", y_test.shape)
# Out:
# X train Transformed Shape (16000, 10022)
# y train Shape (16000,)
# X test Transformed Shape (4000, 10022)
# y test Shape (4000,)

# %% [markdown]
# ### For fast and efficieant training use scaled data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler_fit=scaler.fit(x_train_tf)
x_train_tf_std=scaler_fit.transform(x_train_tf)
x_test_tf_std=scaler_fit.transform(x_test_tf)
print(x_test_tf_std[:2])
# Out:
# [[-0.02113357 -0.06602422 -0.04121219 ... -1.16431042 -3.35051687
#   -0.34880883]
#  [-0.02113357 -0.06602422 -0.04121219 ...  0.14208782 -0.17650721
#    0.8216159 ]]

# %%
with mlflow.start_run():
    mlflow.set_tag("Owner","Suraj H")
    mlflow.set_tag("Algorithm", "ANN adv")

    model=Sequential()
    model.add(Dense(units=32, activation='relu'))
    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dense(units=256, activation='relu'))
    model.add(Dense(units=1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics='accuracy')
    model.fit(x_train_tf_std, y_train, epochs=5, batch_size=32,validation_data=(x_test_tf_std, y_test))

    y_pred=model.predict(x_test_tf_std)
    y_pred=np.where(y_pred>0.5, 1, 0)
    y_pred=y_pred.flatten()
    acc=accuracy_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    
    print("----------------------------------------------------------")
    print("Acuuracy={}\nPrecission={}\nRecall={}\nF1 Score={}".format(acc, precision, recall, f1))
    print("----------------------------------------------------------")
    print("Confusion Matrix=\n")
    sns.heatmap(confusion_matrix(y_test,y_pred), annot=True, annot_kws={"fontsize":15}, linewidths=5, linecolor='blue',
                yticklabels=["Non-Duplicate","Duplicate"], xticklabels=["Non-Duplicate","Duplicate"], cbar=None, fmt='g')
    plt.xlabel("Predicted",fontsize=18)
    plt.ylabel("Actual",fontsize=18)
    plt.savefig("resources_advance_approach_using_extracted_features/ANN_adv_conf_matrix.png")
    plt.show()
    print("----------------------------------------------------------")
    print("Out of {} testing values {} are mis-classified.".format(y_test.shape[0], sum(y_test!=y_pred)))
    print("----------------------------------------------------------")
    print("Classification Report=\n", classification_report(y_test,y_pred))
    print("----------------------------------------------------------")
    
    mlflow.log_metrics({"Accuracy":acc, "Precision":precision, "Recall":recall, "F1 Score":f1})
    #mlflow.sklearn.log_model(model, artifact_path="models")
    mlflow.log_artifact("resources_advance_approach_using_extracted_features/ANN_adv_conf_matrix.png")
# Out:
# Epoch 1/5
# 500/500 [==============================] - 444s 417ms/step - loss: 0.5383 - accuracy: 0.7251 - val_loss: 0.5074 - val_accuracy: 0.7445
# Epoch 2/5
# 500/500 [==============================] - 13s 25ms/step - loss: 0.3013 - accuracy: 0.8626 - val_loss: 0.6408 - val_accuracy: 0.7345
# Epoch 3/5
# 500/500 [==============================] - 12s 24ms/step - loss: 0.1741 - accuracy: 0.9225 - val_loss: 0.9016 - val_accuracy: 0.7290
# Epoch 4/5
# 500/500 [==============================] - 12s 23ms/step - loss: 0.1019 - accuracy: 0.9583 - val_loss: 1.3340 - val_accuracy: 0.7280
# Epoch 5/5
# ...
# 125/125 [==============================] - 1s 7ms/step
# ----------------------------------------------------------
# Acuuracy=0.711
# Precission=0.7107692307692308
# Recall=0.7007077856420627
# F1 Score=0.7057026476578412
# ----------------------------------------------------------
# Confusion Matrix=
# ----------------------------------------------------------
# ...

# %% [markdown]
# **<code style="color:green">Inference:<br>1. Accuracy of the Simple Artificial Neural Network Model is 71%. <br>2. Out of total non-duplicate predicted class 71% are accurate and Out of total duplicate predicted class 71% are accurate.<br>3. Out of total actual non-duplicates class 72% are predicted accuractely and Out of total actual duplicates class 70% are predicted accuractely.<br>4. f1 score for non-duplicate class is 72% and for duplicate class is 71%.<br>5. f1 score for both the classes should be high..</code>**

# %% [markdown]
# ### Inference of Advance Approach with Extracted Features:
# 1. **Accuracy is high(79%) in XGBoost.**
# 2. **Precission is high(75%) in XGBoost.**
# 3. **Recall score is high(88%) in XGBoost.**
# 4. **F1 score is high(81%) in XGBoost**
# 5. **In the advance approach after doing text preprocesing and using BOW vectorizer the "XGBoost" model performance is good.**

# %% [markdown]
# **+---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+ +---------------------------------+-------------------------------------------+------------------------------------------+-----------------------------------------+--------------------------------------+**
